# %% [markdown]
# # WEB SCRAPING WITH BEAUTIFUL SOUP

# %% [markdown]
# Web scraping is the process of extracting data from websites, and Python provides powerful libraries
# like Beautiful Soup 4 that make it easier to scrape and parse HTML and XML content.

# %% [markdown]
# Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# We are collecting data of computer peripherals from "MD Computers" site using Beautiful Soup 4

# %% [markdown]
# Enter the item which you wanted to collect information.

# %%
search_item = input("Which item do you want to search? ")

# %% [markdown]
# From the dynamic url of the website we are formatting the search result to the url.

# %%
url = f"https://mdcomputers.in/index.php?submit_search=&route=product%2Fsearch&&search={search_item}"

# %% [markdown]
# Parsing the html content of the page.

# %%
page_ = requests.get(url).text
doc = BeautifulSoup(page_, "html.parser")

# %% [markdown]
# Finding the total number of result pages by filtering the html tags through class name

# %%
#total_pages_x = doc.find(class_="col-sm-6 text-right")
total_pages_x = doc.find(class_="col-md-6 text-md-end mb-2")

# %%
total_pages_x.text.split("(")[1].split(" ")[0]
# Out:
# '8'

# %%
total_pages = int(total_pages_x.text.split("(")[1].split(" ")[0])

# %%
total_pages
# Out:
# 8

# %% [markdown]
# Total page results obtained for the search

# %%
total_pages
# Out:
# 8

# %% [markdown]
# We are going to gather the item's name , its link , its price (old and new) below

# %% [markdown]
# Creating empty lists for the data

# %%
link = []
item_name = []
new_price = []
old_price = []

# %% [markdown]
# Here is the main code which scrape the information from the html code

# %% [markdown]
# From this url , we can search for the products we need , through iterating the pages till the total page results we obtained earlier.

# %%
for page in range(1, total_pages + 1):
    url = f"https://mdcomputers.in/index.php?route=product/search&page={page}&search={search_item}"
    print(url)
    page_ = requests.get(url).text
    doc = BeautifulSoup(page_, "html.parser")
    
    items = doc.find_all(class_ = "product-wrapper") #Finding the main div tag for each product which holds the data. 
    print(items)
    for item in items:
        
        link.append((item.find("h3")).find("a")['href']) #finding the link through href attribute
        item_name.append(((item.find("h3")).find("a")).text) #finding the name in the h3 tag
        old_price.append(((item.find("span",class_ = "del")).find("span",class_ = "amount")).text[1:]) #finding the old price
        new_price.append(((item.find("span",class_ = "ins")).find("span",class_ = "amount")).text[1:])
        #try:
            #In some Products, there is no old price so in order to clear the error , finding the old price in this try block
        #    old_price.append(((item.find("div",class_ = "price")).find("span",class_ = "price-old")).string[1:])    
        #except:
        #    #For the products having no old price , it is declared as null
        #    old_price.append(None)
# Out:
# https://mdcomputers.in/index.php?route=product/search&page=1&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/asus-tuf-gaming-m4-wireless-mouse"><div class="product-labels labels-rectangular"><span class="onsale product-label">-48%</span></div><img alt="Asus TUF Gaming M4 Wireless Gaming Mouse (Black)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/asus/tuf-gaming-m4-wireless/tuf-gaming-m4-wireless-image-main.png"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('20099');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/asus-tuf-gaming-m4-wireless-mouse"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('20099');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('20099');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/asus-tuf-gaming-m4-wireless-mouse">Asus TUF Gaming M4 Wireless Gaming Mouse (Black)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹6,999</span></span></span><span class="ins"><span class="amount"> ₹3,639<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/razer-deathadder-essential-white-mouse-rz01-03850200-r3m1"><div class="product-labels labels-rectangular"><span class="onsale product-label">-73%</span></div><img alt="Razer Deathadder Essential White Wired Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/razer/rz01-03850200-r3m1/rz01-03850200-r3m1-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('15110');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/razer-deathadder-essential-white-mouse-rz01-03850200-r3m1"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('15110');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('15110');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/razer-deathadder-essential-white-mouse-rz01-03850200-r3m1">Razer Deathadder Essential White Wired Gaming Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹4 ...
# https://mdcomputers.in/index.php?route=product/search&page=2&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/rapoo-vt200-mouse"><div class="product-labels labels-rectangular"><span class="onsale product-label">-15%</span></div><img alt="Rapoo VT200 Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/rapoo/vt200/vt200-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('13126');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/rapoo-vt200-mouse"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('13126');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('13126');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/rapoo-vt200-mouse">Rapoo VT200 Gaming Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹3,000</span></span></span><span class="ins"><span class="amount"> ₹2,550<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/rapoo-vt300-mouse"><div class="product-labels labels-rectangular"><span class="onsale product-label">-37%</span></div><img alt="Rapoo VT300 Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/rapoo/vt300/vt300-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('13127');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/rapoo-vt300-mouse"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('13127');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('13127');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/rapoo-vt300-mouse">Rapoo VT300 Gaming Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹3,299</span></span></span><span class="ins"><span class="amount"> ₹2,075<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/rapoo-vt900-mouse"><div class="product-labels labels-rectan ...
# https://mdcomputers.in/index.php?route=product/search&page=3&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/razer-deathadder-v2-x-wireless-mouse-rz01-04130100-r3a1"><div class="product-labels labels-rectangular"><span class="onsale product-label">-70%</span></div><img alt="Razer DeathAdder V2 X HyperSpeed Wireless Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/razer/rz01-04130100-r3a1/rz01-04130100-r3a1-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('16073');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/razer-deathadder-v2-x-wireless-mouse-rz01-04130100-r3a1"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('16073');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('16073');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/razer-deathadder-v2-x-wireless-mouse-rz01-04130100-r3a1">Razer DeathAdder V2 X HyperSpeed Wireless Gaming Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹8,999</span></span></span><span class="ins"><span class="amount"> ₹2,695<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/ant-esports-mp320s-mouse-pad"><div class="product-labels labels-rectangular"><span class="onsale product-label">-75%</span></div><img alt="Ant Esports MP320S Speed Gaming Mouse Pad (Large Extended)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse%20pad/ant-esports/mp320s/mp320s-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('16195');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/ant-esports-mp320s-mouse-pad"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('16195');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('16195');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/ant-esports-mp320s-mouse-pad">Ant Esports MP320S Speed Gaming Mouse Pad (Large Extended)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹1,499</span></s ...
# https://mdcomputers.in/index.php?route=product/search&page=4&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/ant-esports-gm40-mouse"><div class="product-labels labels-rectangular"><span class="onsale product-label">-50%</span></div><img alt="Ant Esports GM40 RGB Gaming Mouse (Black)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/ant-esports/gm40-rgb/gm40-rgb-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('18687');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/ant-esports-gm40-mouse"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('18687');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('18687');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/ant-esports-gm40-mouse">Ant Esports GM40 RGB Gaming Mouse (Black)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹599</span></span></span><span class="ins"><span class="amount"> ₹300<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/adata-xpg-mouse-pad-battleground-l-bk-ogcww"><div class="product-labels labels-rectangular"><span class="onsale product-label">-23%</span></div><img alt="Adata XPG Battleground L Gaming Mouse Pad (Large)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse%20pad/adata/Battleground-l-bk-ogcww/battleground-l-bk-ogcww-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('18799');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/adata-xpg-mouse-pad-battleground-l-bk-ogcww"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('18799');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('18799');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/adata-xpg-mouse-pad-battleground-l-bk-ogcww">Adata XPG Battleground L Gaming Mouse Pad (Large)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹1,699</span></span></span><span class="ins"><span class="amount"> ₹1,300<span class=""></span></span></ ...
# https://mdcomputers.in/index.php?route=product/search&page=5&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/razer-cobra-mouse-rz01-04650100-r3m1"><div class="product-labels labels-rectangular"><span class="onsale product-label">-46%</span></div><img alt="Razer Cobra RGB Black Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/razer/rz01-04650100-r3m1/rz01-04650100-r3m1-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('20668');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/razer-cobra-mouse-rz01-04650100-r3m1"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('20668');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('20668');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/razer-cobra-mouse-rz01-04650100-r3m1">Razer Cobra RGB Black Gaming Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹4,999</span></span></span><span class="ins"><span class="amount"> ₹2,685<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/razer-cobra-pro-wireless-mouse-rz01-04660100-r3a1"><div class="product-labels labels-rectangular"><span class="onsale product-label">-46%</span></div><img alt="Razer Cobra Pro Wireless Gaming Mouse (Black)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/razer/rz01-04660100-r3a1/rz01-04660100-r3a1-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('20802');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/razer-cobra-pro-wireless-mouse-rz01-04660100-r3a1"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('20802');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('20802');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/razer-cobra-pro-wireless-mouse-rz01-04660100-r3a1">Razer Cobra Pro Wireless Gaming Mouse (Black)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹21,299</span></span></span><span class="ins"><span class="amoun ...
# https://mdcomputers.in/index.php?route=product/search&page=6&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/logitech-g305-lightspeed-wireless-mouse-910-006041"><div class="product-labels labels-rectangular"><span class="onsale product-label">-26%</span></div><img alt="Logitech G305 Lightspeed Wireless Gaming Mouse (Black)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/logitech/910-006041/910-006041-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('22893');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/logitech-g305-lightspeed-wireless-mouse-910-006041"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('22893');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('22893');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/logitech-g305-lightspeed-wireless-mouse-910-006041">Logitech G305 Lightspeed Wireless Gaming Mouse (Black)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹3,795</span></span></span><span class="ins"><span class="amount"> ₹2,790<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/ant-esports-retro-mini-wl-keyboard-mouse-combo-wkm44-brown"><div class="product-labels labels-rectangular"><span class="onsale product-label">-63%</span></div><img alt="Ant Esports WKM44 Wireless Keyboard and Mouse Combo (Brown)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/keyboard-mouse-combo/ant%20esports/wkm44-brown/wkm44-image-1.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('23033');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/ant-esports-retro-mini-wl-keyboard-mouse-combo-wkm44-brown"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('23033');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('23033');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/ant-esports-retro-mini-wl-keyboard-mouse-combo-wkm44-brown">Ant Esports WKM44 Wireless Keyboard and Mouse Combo (Brown)</a></h3><span class="p ...
# https://mdcomputers.in/index.php?route=product/search&page=7&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/logitech-g-pro-x-superlight-2-dex-wl-mouse-910-007359"><div class="product-labels labels-rectangular"><span class="onsale product-label">-31%</span></div><img alt="Logitech G Pro X Superlight 2 DEX Wireless Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/logitech/910-007359/910-007359-image.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('23794');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/logitech-g-pro-x-superlight-2-dex-wl-mouse-910-007359"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('23794');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('23794');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/logitech-g-pro-x-superlight-2-dex-wl-mouse-910-007359">Logitech G Pro X Superlight 2 DEX Wireless Gaming Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹17,995</span></span></span><span class="ins"><span class="amount"> ₹12,400<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/logitech-m241-silent-wireless-mouse-910-007416"><div class="product-labels labels-rectangular"><span class="onsale product-label">-27%</span></div><img alt="Logitech M241 Silent Bluetooth Graphite Wireless Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/logitech/910-007416/910-007416-image.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('23829');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/logitech-m241-silent-wireless-mouse-910-007416"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('23829');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('23829');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/logitech-m241-silent-wireless-mouse-910-007416">Logitech M241 Silent Bluetooth Graphite Wireless Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span cla ...
# https://mdcomputers.in/index.php?route=product/search&page=8&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/ant-esports-km550-pro-wireless-keyboard-mouse-combo"><div class="product-labels labels-rectangular"><span class="onsale product-label">-63%</span></div><img alt="Ant Esports KM550 Pro Wireless Keyboard and Mouse Combo" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/combo/ant-esports/km550-pro-wireless-black/km550-pro-wireless-black-image-main.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('24490');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/ant-esports-km550-pro-wireless-keyboard-mouse-combo"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('24490');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('24490');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/ant-esports-km550-pro-wireless-keyboard-mouse-combo">Ant Esports KM550 Pro Wireless Keyboard and Mouse Combo</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹3,999</span></span></span><span class="ins"><span class="amount"> ₹1,480<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/hp-m310-dual-mode-wireless-mouse-ab3c8aa"><div class="product-labels labels-rectangular"><span class="onsale product-label">-61%</span></div><img alt="HP M310 Dual Mode Wireless Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/h-p/ab3c8aa/ab3c8aa-image-main.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('24533');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/hp-m310-dual-mode-wireless-mouse-ab3c8aa"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('24533');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('24533');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/hp-m310-dual-mode-wireless-mouse-ab3c8aa">HP M310 Dual Mode Wireless Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹1,799</span></span></span><span c ...

# %%
len(item_name)
# Out:
# 145

# %%
len(link)
# Out:
# 145

# %%
sorted(item_name)
# Out:
# ['ANT ESPORTS KM550 Keyboard and Mouse Combo',
#  'ANT ESPORTS Thunder 10 RGB Keyboard and Mouse Combo with Brown Switches',
#  'ANT ESPORTS Thunder 30 RGB Keyboard and Mouse Combo',
#  'ASUS ROG Keris II ACE Wireless RGB Gaming Mouse',
#  'ASUS ROG Keris II ACE Wireless RGB Moonlight White Gaming Mouse',
#  'ASUS ROG Strix Impact III Wireless RGB Gaming Mouse',
#  'AVerMedia Elena Chan Mouse Pad (Large)',
#  'Adata XPG Battleground L Exoskeleton Totem Edition Gaming Mouse Pad (Large)',
#  'Adata XPG Battleground L Gaming Mouse Pad (Large)',
#  'Adata XPG Infarex M20 RGB',
#  'Adata XPG Primer RGB Gaming Mouse (Black)',
#  'Adata XPG Slingshot RGB Gaming Mouse',
#  'Ant Esports AEC410 Type-C To USB Hub',
#  'Ant Esports Cherry Storm Gaming Mousepad - Cherry Red',
#  'Ant Esports GM320 RGB Gaming Mouse (Black)',
#  'Ant Esports GM325 PRO Mini Wireless Gaming Mouse',
#  'Ant Esports GM330 RGB Gaming Mouse (Black)',
#  'Ant Esports GM333 Gaming Mouse (Black-Red-Yellow)',
#  'Ant Esports GM333 Gaming Mouse (Blue-White-Yellow)',
#  'Ant Esports GM340 RGB Gaming Mouse (Black)',
#  'Ant Esports GM40 RGB Gaming Mouse (Black)',
#  'Ant Esports GM50 Gaming Mouse (Black)',
#  'Ant Esports GM600 RGB Gaming Mouse (Black)',
#  'Ant Esports GM610 RGB Gaming Mouse',
#  'Ant Esports GM700 Wireless Gaming Mouse (Black)',
#  'Ant Esports KM1600 Gaming Keyboard and Mouse Combo',
#  'Ant Esports KM1610 Gaming Keyboard and Mouse Combo',
#  'Ant Esports KM1650 Pro Gaming Keyboard and Mouse Combo (Black)',
#  'Ant Esports KM500W Gaming Keyboard And Mouse Combo',
#  'Ant Esports KM550 Pro Wireless Keyboard and Mouse Combo',
#  'Ant Esports MKWM2023 Gaming Keyboard And Mouse Combo',
#  'Ant Esports MP 290 Gaming Mouse Pad (Large)',
#  'Ant Esports MP265 Gaming Mouse Pad (Medium)',
#  'Ant Esports MP280S Speed Gaming Mouse Pad (Large)',
#  'Ant Esports MP320C Control Gaming Mouse Pad (Large Extended)',
#  'Ant Esports MP320S Speed Gaming Mouse Pad (Large Extended)',
#  'Ant Esports MP400R RGB XL Gaming Mouse Pad (Extra Large)',
#  'Ant Esports WKM22 Wireless Keyboard and Mouse Combo',
#  'Ant Esports WKM33 Wireless Keyboard and Mouse Combo (Apple Green)',
#  'Ant Esports WKM33 Wireless Keyboard and Mouse Combo (Cherry Red)',
#  'Ant Esports WKM44 Wireless Keyboard and Mouse Combo (Brown)',
#  'Asus MW103 Wireless Mouse (Balck)',
#  'Asus ROG Harpe Ace Mini Wireless RGB Gaming Mouse',
#  'Asus ROG Harpe Ace Mini Wireless RGB White Gaming Mouse',
#  'Asus TUF Gaming M4 Wireless Gaming Mouse (Black)',
#  'Cooler Master MM311 Wireless Gaming Mouse',
#  'Cooler Master MM311 Wireless Gaming Mouse (White)',
#  'Cooler Master MP511 Black Mouse Pad (Large Extended)',
#  'Cooler Master MP511 Gaming Mouse Pad (Large)',
#  'Cosmic Byte Atlas Tri-Mode White Wireless Gaming Mouse',
#  'Cosmic Byte Atlas Tri-Mode Wireless Gaming Mouse',
#  'Cosmic Byte CB-GKM-19 Dragonfly Keyboard and Mouse Combo',
#  'Cosmic Byte Firestorm RGB White Wired Gaming Mouse',
#  'Cybeart Gryffindor Classic Gaming Mouse Pad (Large)',
#  'Cybeart Hogwarts Gaming Mouse Pad (Large)',
#  'Cybeart Mortal Kombat Gaming Mouse Pad (Large)',
#  'Cybeart Mortal Kombat Gaming Mouse Pad (XXL)',
#  'Cybeart The Flash Gaming Mouse Pad (Large)',
#  'Dell D SELECT DS111 Mouse',
#  'Dell D SELECT DS320 Wireless Mouse',
#  'Dell KM3322W Keyboard and Mouse Wireless Combo',
#  'Dell MS116 Wired Mouse',
#  'Dell WM118 Wireless Mouse (Black)',
#  'Dell WM126 Optical Wireless Mouse',
#  'EVM Classy 3W042 Wireless Mouse (Black)',
#  'EVM EVO 3W042 Wireless Mouse (Grey)',
#  'EVM EnGrip EWLM-360 Wireless Silver PC Mouse',
#  'EVM EnHawk 7B23 Gaming Keyboard and Mouse Combo (White)',
#  'EVM Enorb EWLM-360 Wireless Mouse (Black)',
#  'EVM M06063 Wired Gaming Mouse (Black)',
#  'EVM WIFI Keyboard and Mouse Combo WLKM-036',
#  'EVM Wired Optical Mouse - Black Grey (EVM-M009)',
#  'Fingers Magnifico Duo Keyboard and Mouse Combo (Black)',
#  'Galax Slider-03 RGB Gaming Mouse',
#  'Galax Xanova Deimos Luxe-R RGB Gaming Mouse Pad',
#  'Gamdias Aura GS 2 Gaming Mouse (Black)',
#  'Gamdias Aura GS3 Gaming Mouse (Black)',
#  'Gamdias Aura GS4 Gaming Mouse (Black)',
#  'Gamdias Hermes E4 3-IN-1 Combo (White)',
#  'Glorious Model D RGB Wireless Gaming Mouse (Matte Black)',
#  'Glorious PC Gaming Race Cleaning Kit for Keyboard and Mouse',
#  'HP KM150 Keyboard and Mouse Combo',
#  'HP KM200 Wireless Keyboard and Mouse Combo',
#  'HP M310 Dual Mode Wireless Mouse',
#  'HP S500 Wireless Mouse (Black)',
#  'HyperX Pulsefire Core RGB Gaming Mouse (Black)',
#  'Lenovo 120 Wired Mouse (Black)',
#  'Lenovo 130 Wireless Mouse',
#  'Lenovo 160 Wired Keyboard and Mouse Combo',
#  'Lenovo WL310 Bluetooth Silent Wireless Grey Mouse',
#  'Logitech G Pro 2 Lightspeed Wireless Gaming Mouse',
#  'Logitech G Pro Wireless Gaming Mouse',
#  'Logitech G Pro X Superlight 2 DEX Pink Wireless Gaming Mouse',
#  'Logitech G Pro X Superlight 2 DEX White Wireless Gaming Mouse',
#  'Logitech G Pro X Superlight 2 DEX Wireless Gaming Mouse',
#  'Logitech G203 Lightsync RGB Gaming Mouse',
#  'Logitech G203 Lightsync RGB Gaming Mouse (White)',
#  'Logitech G304 Lightspeed Wireless Gaming Mouse (Black)',
#  'Logitech G305 Lightspeed Wireless Gaming Mouse (Black)',
#  'Logitech G402 Hyperion Fury Gaming Mouse',
#  'Logitech G502 HERO RGB Gaming Mouse (Black)',
#  'Logitech G502 X Black Gaming Mouse',
#  'Logitech G502 X Gaming Mouse (White)',
#  'Logitech G502 X Plus Lightspeed RGB Wireless Gaming Mouse (White)',
#  'Logitech G840 XL Black Gaming Mouse Pad (Extra Large)',
#  'Logitech G840 XL Pink Gaming Mouse Pad (Extra Large)',
#  'Logitech M171 Wireless Gaming Mouse (Blue-Gray)',
#  'Logitech M196 Graphite Bluetooth Wireless Mouse',
#  'Logitech M220 Silent Wireless Mouse',
#  'Logitech M241 Silent Bluetooth Graphite Wireless Mouse',
#  'Logitech M90 Mouse (Black)',
#  'Logitech MK120 Keyboard and Mouse Combo',
#  'Logitech MK200 Keyboard and Mouse Combo',
#  'Logitech MK220 Wireless Combo',
#  'Logitech MK235 Wireless Keyboard and Mouse Combo',
#  'Logitech MK275 Wireless Keyboard and Mouse Combo',
#  'Logitech MX Master 3S Wireless Mouse (Graphite)',
#  'Logitech PEBBLE 2 Tonal Graphite Keyboard and Mouse Combo',
#  'Logitech Pebble 2 M350S Graphite Wireless Mouse',
#  'Rapoo V16 Gaming Mouse (Black)',
#  'Rapoo V280 Gaming Mouse (Black)',
#  'Rapoo VT200 Gaming Mouse',
#  'Rapoo VT30 Gaming Mouse (Black)',
#  'Rapoo VT300 Gaming Mouse',
#  'Rapoo VT900 Gaming Mouse',
#  'Razer Basilisk V3 Gaming Mouse (Black)',
#  'Razer Basilisk V3 Pro Wireless Gaming Mouse (Black)',
#  'Razer Bungee V3 Chroma Mouse Cable Management',
#  'Razer Cobra Pro Wireless Gaming Mouse (Black)',
#  'Razer Cobra Pro Wireless Gaming Mouse (White)',
#  'Razer Cobra RGB Black Gaming Mouse',
#  'Razer DeathAdder V2 X HyperSpeed Wireless Gaming Mouse',
#  'Razer DeathAdder V3 Gaming Mouse (Black)',
#  'Razer DeathAdder V3 Pro Wireless Gaming Mouse (Black)',
#  'Razer Deathadder Essential White Wired Gaming Mouse',
#  'Razer Goliathus Mobile Stealth Edition Soft Gaming Mouse Pad',
#  'Razer Mouse Dock Pro (Magnetic Wireless Charging Dock for Razer Basillisk V3 Pro, Chroma RGB Underglow)',
#  'Razer Naga V2 Pro Wireless Gaming Mouse (Black)',
#  'Razer Orochi V2 Wireless Gaming Mouse (Black)',
#  'Razer Orochi V2 Wireless Gaming Mouse (White)',
#  'Razer Sphex V3 Ultra Thin Gaming Mouse Pad (Large)',
#  'Razer Viper V3 Pro Wireless Gaming Mouse (Black)',
#  'Razer Wireless Mouse Charging Dock',
#  'Thermaltake Argent M5 Gaming Mouse (Black)',
#  'Thermaltake Argent MP1 RGB Gaming Mouse Pad (Medium)']

# %% [markdown]
# Converting the lists to Dictionary and then to DataFrame.

# %%
my_dict = {'item_name': item_name , 'link': link , 'new_price': new_price , 'old_price': old_price}

# %%
len(old_price)
# Out:
# 145

# %%
for key in my_dict:
    print(len(my_dict[key]))
# Out:
# 145
# 145
# 145
# 145

# %%
df = pd.DataFrame(my_dict)

# %% [markdown]
# Here is our DataFrame with required data

# %%
df
# Out:
#                                              item_name  \
# 0     Asus TUF Gaming M4 Wireless Gaming Mouse (Black)
# 1    Razer Deathadder Essential White Wired Gaming ...
# 2    Logitech G502 X Plus Lightspeed RGB Wireless G...
# 3                 Logitech G502 X Gaming Mouse (White)
# 4              Logitech MK200 Keyboard and Mouse Combo
# ..                                                 ...
# 140  Ant Esports KM550 Pro Wireless Keyboard and Mo...
# 141                   HP M310 Dual Mode Wireless Mouse
# 142   Cosmic Byte Atlas Tri-Mode Wireless Gaming Mouse
# 143  Cosmic Byte Atlas Tri-Mode White Wireless Gami...
# 144  Cosmic Byte Firestorm RGB White Wired Gaming M...
#
#                                                   link new_price old_price
# 0    https://mdcomputers.in/product/asus-tuf-gaming...    ₹3,639     6,999
# 1    https://mdcomputers.in/product/razer-deathadde...    ₹1,199     4,499
# 2    https://mdcomputers.in/product/logitech-g502-x...   ₹12,440    14,700
# 3    https://mdcomputers.in/product/logitech-g502-x...    ₹5,980     7,995
# 4    https://mdcomputers.in/product/logitech-mk200-...    ₹1,080     1,600
# ..                                                 ...       ...       ...
# 140  https://mdcomputers.in/product/ant-esports-km5...    ₹1,480     3,999
# 141  https://mdcomputers.in/product/hp-m310-dual-mo...      ₹700     1,799
# 142  https://mdcomputers.in/product/cosmic-byte-atl...    ₹2,000     2,999
# 143  https://mdcomputers.in/product/cosmic-byte-atl...    ₹2,000     2,999
# 144  https://mdcomputers.in/product/cosmic-byte-fir...      ₹950     1,799
#
# [145 rows x 4 columns]

# %% [markdown]
# Converting the Dataframe to excel document with file name as the item we searched

# %%
df.to_excel(f'{search_item}_list_mdcomputers.xlsx')

# %% [markdown]
# Finally we scraped the data from website(MD Computers) successfully through BeautifulSoup4.
