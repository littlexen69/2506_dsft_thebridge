# %% [markdown]
# # Descargas de diferentes fuentes de la web

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# ^C
# Requirement already satisfied: pip in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (25.1.1)

# %%
# %pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (2.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importamos librerias
import requests
import zipfile
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ## Primera petición

# %%
url = "https://m.media-amazon.com/images/M/MV5BZGUzYTI3M2EtZmM0Yy00NGUyLWI4ODEtN2Q3ZGJlYzhhZjU3XkEyXkFqcGdeQXVyNTM0OTY1OQ@@._V1_.jpg"

# %%
# Out:
# <Response [200]>

# %% [markdown]
# ## Bajar datos de inflación mediante url

# %%
df_inflaction = pd.read_csv("https://datahub.io/core/inflation/r/inflation-gdp.csv")
# Out:
#   Country Country Code  Year  Inflation
# 0   Aruba          ABW  1985   4.032258
# 1   Aruba          ABW  1986   1.073966
# 2   Aruba          ABW  1987   3.643045
# 3   Aruba          ABW  1988   3.121868
# 4   Aruba          ABW  1989   3.991628

# %%
df_inflaction["Country"] == "Spain"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11034    False
# 11035    False
# 11036    False
# 11037    False
# 11038    False
# Name: Country, Length: 11039, dtype: bool

# %%
df_inflaction[df_inflaction["Country"] == "Spain"]
# Out:
#      Country Country Code  Year  Inflation
# 2865   Spain          ESP  1960   1.177771
# 2866   Spain          ESP  1961   0.809253
# 2867   Spain          ESP  1962   5.706477
# 2868   Spain          ESP  1963   8.743698
# 2869   Spain          ESP  1964   6.979247
# ...      ...          ...   ...        ...
# 2924   Spain          ESP  2019   0.699519
# 2925   Spain          ESP  2020  -0.322753
# 2926   Spain          ESP  2021   3.093135
# 2927   Spain          ESP  2022   8.390576
# 2928   Spain          ESP  2023   3.532361
#
# [64 rows x 4 columns]

# %% [markdown]
# ## Bajar datos de Bicimad

# %%
url = "https://opendata.emtmadrid.es/getattachment/c3383795-121b-4ebf-98b4-c7b05e902eaf/202106_movements.aspx"

# %%
# Out:
# <Response [200]>

# %%
# Guardamos el zip

# %%
# Extraemos lo que hay dentro

# %%
# Leemos los datos

# %%
# Vemos qué pinta tienen
datos_bicis.head()
# Out:
#                                     _id  \
# 0  {'$oid': '60bbf3f21b91311d90d568ad'}
# 1  {'$oid': '60bbf3f21b91311d90d568b2'}
# 2  {'$oid': '60bbf3f21b91311d90d568b3'}
# 3  {'$oid': '60bbf3f21b91311d90d568b4'}
# 4  {'$oid': '60bbf3f21b91311d90d568b5'}
#
#                                        user_day_code  idplug_base  user_type  \
# 0  b67ea824acf706087d5818ebc6f90821a5abaab17a0868...           15          1
# 1  364b1b99f1f9a1748f7abf1134c8d6a46197b583649308...            7          1
# 2  5cc17031cba02835dda4b6c153b56572beaade54d8ab91...           14          1
# 3  6e855acaaa17d6d14236598c0f1172c783e16950e39c01...            8          1
# 4  e93417502d55208995a61f4177956ab9289aba39044ce3...            1          1
#
#    idunplug_base  travel_time  idunplug_station  ageRange  idplug_station  \
# 0             13          319                38         0              54
# 1              1          386               185         0             126
# 2             10          465                15         0              91
# 3             22          613                84         0             236
# 4              4          751               131         5              94
#
#         unplug_hourTime zip_code
# 0  2021-06-01T00:00:00Z
# 1  2021-06-01T00:00:00Z
# 2  2021-06-01T00:00:00Z
# 3  2021-06-01T00:00:00Z
# 4  2021-06-01T00:00:00Z    28006

# %%
# Informacion dataframe
datos_bicis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               10000 non-null  object
#  1   user_day_code     10000 non-null  object
#  2   idplug_base       10000 non-null  int64
#  3   user_type         10000 non-null  int64
#  4   idunplug_base     10000 non-null  int64
#  5   travel_time       10000 non-null  int64
#  6   idunplug_station  10000 non-null  int64
#  7   ageRange          10000 non-null  int64
#  8   idplug_station    10000 non-null  int64
#  9   unplug_hourTime   10000 non-null  object
#  10  zip_code          10000 non-null  object
# dtypes: int64(7), object(4)
# memory usage: 859.5+ KB

# %%
# Valores unicos de la columna zip_code
datos_bicis["zip_code"].unique()
# Out:
# array(['', '28006', '28004', '28045', '28028', '28009', '28007', '28005',
#        '28010', '28034', '28012', '28001', '28008', '28015', '28002',
#        '28105', 'CODIGO_POSTAL_NOT_DEF', '28013', '39724', '28100',
#        '28800', '28027', '28020', '28011', '28014', '28850', '15002',
#        '28003', '45007', '28046', '28039', '28043', '28038', '28934',
#        '28016', '28945', '28221', '28033', '28030', '28029', '28048',
#        '28054', '28035', '35572', '28049', '28004 ', '28019', '28040',
#        '28941', '28523', '28380', '28933', '28026', '45600', '28938',
#        '28220', '28935', '28760', '28863', '28018', '28250', '28053',
#        '28017', '28024', '28823', '28021', '28922', '28210', '28022',
#        '28036', '28047', '28430', '28041', '46009', '28770', '28031',
#        '28200', '46026', '20540', '28232', '28042', '28071', '18006',
#        '28400', '62973', '2', '28521', '28822', '28411', '28229', '48520',
#        '29039', '28260', '28055', '28942', '28815', '28037', '28702',
#        '28707', '28701', '28290', '28691', '28460', '28936', '28915',
#        '28025', '28750', '28905', '28223', '75014', '28891', '28903',
#        '23009', '28023', '28660', '28006 ', '28924', '28911', '28032',
#        '28801', '10318', '28803', '29740', '28051', '28342', '28912',
#        '28064', '28299', '33206', '28791', '28028 ', '09006', '28917',
#        '19160', '28923', '28350', '29045', '23012', '28670', '28044',
#        '28909', '28450', '28906', '28231'], dtype=object)

# %% [markdown]
# # Acceso a archivos de la pagina de datos.gob.es
# Uno de los mayores catálogos de información pública descargable en España

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio datos.gob.es</h3>
#
# Descarga con pandas un dataset de la página https://datos.gob.es/es/catalogo acerca del empleo y guárdalo en un csv en la carpeta data.
#
#  </td></tr>
# </table>

# %%
# Out:
#   AUTORIDAD_LABORAL       SECTOR  NUM_EXPEDIENTES  NUM_TRABAJADORES_AFECTADOS  \
# 0              D.G.  AGRICULTURA                3                          64
# 1              D.G.  CONSTRUCIÓN               32                        1431
# 2              D.G.    INDUSTRIA              223                       56791
# 3              D.G.    SERVICIOS              664                       38105
# 4       DT VALENCIA  AGRICULTURA               68                         264
#
#    HOMBRES  MUJERES  PERS_GENERO_SIN_DETERMINAR
# 0       50       14                           0
# 1     1189      242                           0
# 2    42703    10146                        3942
# 3    18003    18170                        1932
# 4      200       64                           0

# %%
# Out:
#         PK                                NOMBRE  \
# 0  5949409   Agencia de Proximidad de Arganzuela
# 1  5666151      Agencia de Proximidad de Barajas
# 2  4514901  Agencia de Proximidad de Carabanchel
# 3  5520471       Agencia de Proximidad de Latina
# 4   172696       Agencia de Proximidad de Tetuán
#
#                            DESCRIPCION-ENTIDAD  \
# 0  Agencia de Colocación Autorizada 1300000002
# 1  Agencia de Colocación Autorizada 1300000002
# 2  Agencia de Colocación Autorizada 1300000002
# 3  Agencia de Colocación Autorizada 1300000002
# 4  Agencia de Colocación Autorizada 1300000002
#
#                                   HORARIO  \
# 0  De lunes a viernes de 8:30 a 14 horas.
# 1  De lunes a viernes de 8:30 a 14 horas.
# 2  De lunes a viernes de 8:30 a 14 horas.
# 3  De lunes a viernes de 8:30 a 14 horas.
# 4  De lunes a viernes de 8:30 a 14 horas.
#
#                                         EQUIPAMIENTO  \
# 0  Para las personas desempleadas:   Orientación ...
# 1  Para las personas desempleadas:   Orientación ...
# 2  Para las personas desempleadas:   Orientación ...
# 3  Para las personas desempleadas:   Orientación ...
# 4  Para las personas desempleadas:   Orientación ...
#
#                                           TRANSPORTE  DESCRIPCION  \
# 0  Metro: Puerta de Toledo  Cercanias: Pirámides ...          NaN
# 1         Metro: Alameda de Osuna Bus: 114, 115, 151          NaN
# 2       Metro: Carabanchel Alto Bus: 34, 35, 47, 139          NaN
# 3            METRO/RENFE: Laguna BUS: 25,31,55 y 119          NaN
# 4           Metro: Alvarado Bus: 124, 128, 3, 64, 66          NaN
#
#   ACCESIBILIDAD                                        CONTENT-URL  \
# 0           1,6  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1           1,6  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2           1,6  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 3           1,6  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 4             1  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#          NOMBRE-VIA  ... COD-DISTRITO     DISTRITO  COORDENADA-X  \
# 0          PONTONES  ...          2.0   ARGANZUELA        439268
# 1         CANTABRIA  ...         21.0      BARAJAS        450175
# 2  CARABANCHEL ALTO  ...         11.0  CARABANCHEL        436104
# 3          ALHAMBRA  ...         10.0       LATINA        436899
# 4      JUAN PANTOJA  ...          NaN       TETUAN        440316
#
#    COORDENADA-Y    LATITUD  LONGITUD     TELEFONO FAX  \
# 0       4472945  40.404908 -3.715722  913 643 460 NaN
# 1       4478385  40.454636 -3.587632  917 412 190 NaN
# 2       4469258  40.371456 -3.752637  915 133 085 NaN
# 3       4472004  40.396255 -3.743547  915 088 758 NaN
# 4       4477949  40.450050 -3.703857  915 336 559 NaN
#
#                        EMAIL                                            TIPO
# 0   aparganzuelaae@madrid.es  /contenido/entidadesYorganismos/OficinasEmpleo
# 1      apbarajasae@madrid.es  /contenido/entidadesYorganismos/OficinasEmpleo
# 2  apcarabanchelae@madrid.es  /contenido/entidadesYorganismos/OficinasEmpleo
# 3       aplatinaae@madrid.es  /contenido/entidadesYorganismos/OficinasEmpleo
# 4       aptetuanae@madrid.es  /contenido/entidadesYorganismos/OficinasEmpleo
#
# [5 rows x 32 columns]

# %% [markdown]
# # OpenStreetMap

# %%
# Amenities
# https://wiki.openstreetmap.org/wiki/Key:amenity
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """

"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
print(response)
data = response.json()
# Out:
# <Response [200]>

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.7 375dc00a',
#  'osm3s': {'timestamp_osm_base': '2025-06-17T07:43:24Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 2977298934,
#    'lat': 40.4210523,
#    'lon': -3.689841,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:street': 'Calle de Villalar',
#     'amenity': 'cafe',
#     'cuisine': 'regional',
#     'internet_access': 'yes',
#     'name': 'Café Villalar',
#     'phone': '+34 914358937',
#     'website': 'https://cafeteriavillalar.eatbu.com/'}},
#   {'type': 'node',
#    'id': 3426617375,
#    'lat': 40.4221948,
#    'lon': -3.6923421,
#    'tags': {'addr:housenumber': '21',
#     'addr:street': 'Paseo de Recoletos',
#     'amenity': 'cafe',
#     'check_date': '2024-09-04',
#     'name': 'Gran Café Gijón',
#     'outdoor_seating': 'yes',
#     'phone': '+34 915 215 425',
#     'website': 'https://cafegijon.com/',
#     'wheelchair': 'no',
#     'wikidata': 'Q1025608',
#     'wikipedia': 'es:Café Gijón'}},
#   {'type': 'node',
#    'id': 3426800312,
#    'lat': 40.4232935,
#    'lon': -3.6940419,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '12',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Conde de Xiquena',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Altered'}},
#   {'type': 'node',
#    'id': 4703448419,
#    'lat': 40.4229908,
#    'lon': -3.6936524,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Marqués de Monasterio',
#     'amenity': 'cafe',
#     'check_date': '2024-09-04',
#     'contact:facebook': 'https://www.facebook.com/hermanasae',
#     'contact:instagram': 'https://www.instagram.com/hermanasarce/',
#     'cuisine': 'cake',
#     'disused:amenity': 'restaurant',
#     'name': 'Hermanas Arce',
#     'old_name': 'Noteolvides',
#     'opening_hours': 'Tu-Fr 09:00-17:00; Sa 09:30-17:30',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 4778747544,
#    'lat': 40.4223247,
#    'lon': -3.6909735,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '1',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Recoletos',
#     'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'contact:phone': '+34 914319000',
#     'contact:website': 'https://www.santagloria.com',
#     'name': 'Santagloria',
#     'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 9207850217,
#    'lat': 40.4218751,
#    'lon': -3.6901227,
#    'tags': {'amenity': 'cafe', 'name': 'masticar'}}]}

# %%
data.keys()
# Out:
# dict_keys(['version', 'generator', 'osm3s', 'elements'])

# %%
data["osm3s"]
# Out:
# {'timestamp_osm_base': '2025-06-17T07:43:24Z',
#  'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'}

# %%
data.get("osm3s")
# Out:
# {'timestamp_osm_base': '2025-06-17T07:43:24Z',
#  'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'}

# %%
data["osm3s"]["copyright"]
# Out:
# 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'

# %%
data["elements"][0]
# Out:
# {'type': 'node',
#  'id': 2977298934,
#  'lat': 40.4210523,
#  'lon': -3.689841,
#  'tags': {'addr:city': 'Madrid',
#   'addr:housenumber': '4',
#   'addr:street': 'Calle de Villalar',
#   'amenity': 'cafe',
#   'cuisine': 'regional',
#   'internet_access': 'yes',
#   'name': 'Café Villalar',
#   'phone': '+34 914358937',
#   'website': 'https://cafeteriavillalar.eatbu.com/'}}

# %%
# Acceder a los valores del diccionario para guardarlos en variables para luego crear un Dataframe
dict_cafes = {"lat":[], "lon":[], "street":[], "number_street":[]}
for i in data["elements"]:
    lat = i["lat"]
    lon = i["lon"]
    street = i["tags"].get("addr:street", "Sin Calle")
    number_street = i["tags"].get("addr:housenumber", 0)

    dict_cafes["lat"].append(lat)
    dict_cafes["lon"].append(lon)
    dict_cafes["street"].append(street)
    dict_cafes["number_street"].append(number_street)

df_cafe = pd.DataFrame(dict_cafes)
df_cafe
# Out:
#          lat       lon                           street number_street
# 0  40.421052 -3.689841                Calle de Villalar             4
# 1  40.422195 -3.692342               Paseo de Recoletos            21
# 2  40.423293 -3.694042       Calle del Conde de Xiquena            12
# 3  40.422991 -3.693652  Calle del Marqués de Monasterio             6
# 4  40.422325 -3.690974               Calle de Recoletos             1
# 5  40.421875 -3.690123                        Sin Calle             0

# %%
data["elements"][0]["tags"]["name"]
# Out:
# 'Café Villalar'

# %%
pd.DataFrame(data["elements"])
# Out:
#    type          id        lat       lon  \
# 0  node  2977298934  40.421052 -3.689841
# 1  node  3426617375  40.422195 -3.692342
# 2  node  3426800312  40.423293 -3.694042
# 3  node  4703448419  40.422991 -3.693652
# 4  node  4778747544  40.422325 -3.690974
# 5  node  9207850217  40.421875 -3.690123
#
#                                                 tags
# 0  {'addr:city': 'Madrid', 'addr:housenumber': '4...
# 1  {'addr:housenumber': '21', 'addr:street': 'Pas...
# 2  {'addr:city': 'Madrid', 'addr:housenumber': '1...
# 3  {'addr:city': 'Madrid', 'addr:housenumber': '6...
# 4  {'addr:city': 'Madrid', 'addr:housenumber': '1...
# 5            {'amenity': 'cafe', 'name': 'masticar'}

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.7 375dc00a',
#  'osm3s': {'timestamp_osm_base': '2025-06-17T07:43:24Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 2977298934,
#    'lat': 40.4210523,
#    'lon': -3.689841,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:street': 'Calle de Villalar',
#     'amenity': 'cafe',
#     'cuisine': 'regional',
#     'internet_access': 'yes',
#     'name': 'Café Villalar',
#     'phone': '+34 914358937',
#     'website': 'https://cafeteriavillalar.eatbu.com/'}},
#   {'type': 'node',
#    'id': 3426617375,
#    'lat': 40.4221948,
#    'lon': -3.6923421,
#    'tags': {'addr:housenumber': '21',
#     'addr:street': 'Paseo de Recoletos',
#     'amenity': 'cafe',
#     'check_date': '2024-09-04',
#     'name': 'Gran Café Gijón',
#     'outdoor_seating': 'yes',
#     'phone': '+34 915 215 425',
#     'website': 'https://cafegijon.com/',
#     'wheelchair': 'no',
#     'wikidata': 'Q1025608',
#     'wikipedia': 'es:Café Gijón'}},
#   {'type': 'node',
#    'id': 3426800312,
#    'lat': 40.4232935,
#    'lon': -3.6940419,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '12',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Conde de Xiquena',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Altered'}},
#   {'type': 'node',
#    'id': 4703448419,
#    'lat': 40.4229908,
#    'lon': -3.6936524,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Marqués de Monasterio',
#     'amenity': 'cafe',
#     'check_date': '2024-09-04',
#     'contact:facebook': 'https://www.facebook.com/hermanasae',
#     'contact:instagram': 'https://www.instagram.com/hermanasarce/',
#     'cuisine': 'cake',
#     'disused:amenity': 'restaurant',
#     'name': 'Hermanas Arce',
#     'old_name': 'Noteolvides',
#     'opening_hours': 'Tu-Fr 09:00-17:00; Sa 09:30-17:30',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 4778747544,
#    'lat': 40.4223247,
#    'lon': -3.6909735,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '1',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Recoletos',
#     'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'contact:phone': '+34 914319000',
#     'contact:website': 'https://www.santagloria.com',
#     'name': 'Santagloria',
#     'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 9207850217,
#    'lat': 40.4218751,
#    'lon': -3.6901227,
#    'tags': {'amenity': 'cafe', 'name': 'masticar'}}]}

# %%
def json_to_dataframe(data_entrada):
    elements = data_entrada['elements']
    places = {'lat': [], 'lon': [], 'name': [], 'address': []}

    for i in elements:
        lalitude = i['lat']
        longitude = i['lon']
        name = i['tags'].get('name')
        street = i['tags'].get('addr:street', 'Sin calle')
        number = i['tags'].get('addr:housenumber', 0)
        
        places['lat'].append(lalitude)
        places['lon'].append(longitude)
        places['name'].append(name)
        places['address'].append(str(street) + ' ' + str(number))

    df = pd.DataFrame(places)
    
    return df

# %%
df_return = json_to_dataframe(data)
df_return
# Out:
#          lat       lon             name                            address
# 0  40.421052 -3.689841    Café Villalar                Calle de Villalar 4
# 1  40.422195 -3.692342  Gran Café Gijón              Paseo de Recoletos 21
# 2  40.423293 -3.694042          Altered      Calle del Conde de Xiquena 12
# 3  40.422991 -3.693652    Hermanas Arce  Calle del Marqués de Monasterio 6
# 4  40.422325 -3.690974      Santagloria               Calle de Recoletos 1
# 5  40.421875 -3.690123         masticar                        Sin calle 0

# %%
# lista_responses = [data1, data2, data3, data4]
# for data in lista_responses:
#     df_return = json_to_dataframe(data)
#     df_results = df_results.concat(df_return)

# %% [markdown]
# ## Datos del espacio

# %%
'''
https://thespacedevs.com/llapi
https://ll.thespacedevs.com/2.2.0/swagger
'''

space_url = "http://ll.thespacedevs.com/2.2.0"

# %%
print(response)
response.json()
# Out:
# <Response [200]>
# {'count': 813,
#  'next': 'https://ll.thespacedevs.com/2.2.0/astronaut/?limit=10&offset=10',
#  'previous': None,
#  'results': [{'id': 1,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/1/',
#    'name': 'Thomas Pesquet',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P396DT11H33M45S',
#    'eva_time': 'P1DT15H54M',
#    'age': 47,
#    'date_of_birth': '1978-02-27',
#    'date_of_death': None,
#    'nationality': 'French',
#    'bio': 'Thomas Gautier Pesquet is a French aerospace engineer, pilot, and European Space Agency astronaut. Pesquet was selected by ESA as a candidate in May 2009, and he successfully completed his basic training in November 2010. From November 2016 to June 2017, Pesquet was part of Expeditions 50 and 51 on the International Space Station as a flight engineer.',
#    'twitter': 'https://twitter.com/Thom_astro',
#    'instagram': 'https://instagram.com/thom_astro',
#    'wiki': 'https://en.wikipedia.org/wiki/Thomas_Pesquet',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX,BEL,SVN',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': 'Ariane | Vega',
#     'spacecraft': 'Space Rider',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/esa_patch_float_image_20250211192109.png',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/thomas2520pesquet_image_20200102120546.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190357.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 6,
#    'last_flight': '2021-04-23T09:49:02Z',
#    'first_flight': '2016-11-17T20:20:13Z'},
#   {'id': 2,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/2/',
#    'name': 'Claude Nicollier',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P42DT12H3M12S',
#    'eva_time': 'PT8H10M',
#    'age': 80,
#    'date_of_birth': '1944-09-02',
#    'date_of_death': None,
#    'nationality': 'Swiss',
#    'bio': 'Claude Nicollier is the first astronaut from Switzerland. He has flown on four Space Shuttle missions. His first spaceflight (STS-46) was in 1992, and his final spaceflight (STS-103) was in 1999. He took part in two servicing missions to the Hubble Space Telescope (called STS-61 and STS-103). During his final spaceflight he participated in a spacewalk, becoming the first European Space Agency astronaut to do so during a Space Shuttle mission. In 2000 he was assigned to the Astronaut Office Extravehicular Activity Branch, while maintaining a position as Lead ESA Astronaut in Houston. Nicollier retired from ESA in April 2007.',
#    'twitter': 'https://twitter.com/Astroclaude',
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Claude_Nicollier',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX,BEL,SVN',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': 'Ariane | Vega',
#     'spacecraft': 'Space Rider',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/esa_patch_float_image_20250211192109.png',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/claude2520nicollier_image_20181127203218.jpg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185551.jpeg',
#    'flights_count': 4,
#    'landings_count': 4,
#    'spacewalks_count': 1,
#    'last_flight': '1999-12-20T00:50:00Z',
#    'first_flight': '1992-07-31T13:56:48Z'},
#   {'id': 3,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/3/',
#    'name': 'Tim Peake',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P185DT22H11M51S',
#    'eva_time': 'PT4H43M',
#    'age': 53,
#    'date_of_birth': '1972-04-07',
#    'date_of_death': None,
#    'nationality': 'British',
#    'bio': "Major Timothy Nigel Peake CMG is a British Army Air Corps officer, former European Space Agency astronaut and International Space Station (ISS) crew member.  He is the first British ESA astronaut, the second astronaut to bear a flag of the United Kingdom patch, the sixth person born in the United Kingdom to go on board the International Space Station and the seventh UK-born person in space. He began the ESA's intensive astronaut basic training course in September 2009 and graduated on 22 November 2010",
#    'twitter': 'https://twitter.com/astro_timpeake',
#    'instagram': 'https://www.instagram.com/astro_timpeake/',
#    'wiki': 'https://en.wikipedia.org/wiki/Tim_Peake',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX,BEL,SVN',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': 'Ariane | Vega',
#     'spacecraft': 'Space Rider',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/esa_patch_float_image_20250211192109.png',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/tim_peake_image_20230120154350.jpg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185843.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 1,
#    'last_flight': '2015-12-15T11:03:09Z',
#    'first_flight': '2015-12-15T11:03:09Z'},
#   {'id': 4,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/4/',
#    'name': 'Buzz Aldrin',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P9DT8H43M58S',
#    'eva_time': 'PT8H1M40S',
#    'age': 95,
#    'date_of_birth': '1930-01-20',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Buzz Aldrin; born Edwin Eugene Aldrin Jr.; is an American engineer, former astronaut, and fighter pilot.\r\nAs Lunar Module Pilot on the Apollo 11 mission, he and mission commander Neil Armstrong were the first two humans to land on the Moon.',
#    'twitter': 'https://twitter.com/TheRealBuzz',
#    'instagram': 'https://www.instagram.com/drbuzzaldrin/',
#    'wiki': 'https://en.wikipedia.org/wiki/Buzz_Aldrin',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/buzz_aldrin_image_20220911034547.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185225.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 4,
#    'last_flight': '1969-07-21T17:54:00Z',
#    'first_flight': '1966-11-11T20:46:33Z'},
#   {'id': 5,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/5/',
#    'name': 'Chris Hadfield',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P165DT16H19M',
#    'eva_time': 'PT14H50M',
#    'age': 65,
#    'date_of_birth': '1959-08-29',
#    'date_of_death': None,
#    'nationality': 'Canadian',
#    'bio': 'Chris Austin Hadfield is a Canadian retired astronaut, engineer, and former Royal Canadian Air Force fighter pilot.\r\nThe first Canadian to walk in space, Hadfield has flown two space shuttle missions and served as commander of the International Space Station.',
#    'twitter': 'https://twitter.com/Cmdr_Hadfield',
#    'instagram': 'https://www.instagram.com/colchrishadfield/',
#    'wiki': 'https://en.wikipedia.org/wiki/Chris_Hadfield',
#    'agency': {'id': 16,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/16/',
#     'name': 'Canadian Space Agency',
#     'featured': False,
#     'type': 'Government',
#     'country_code': 'CAN',
#     'abbrev': 'CSA',
#     'description': 'The Canadian Space Agency was established by the Canadian Space Agency Act which received Royal Assent on May 10, 1990. \r\n\r\nThe Canadian space program is administered by the Canadian Space Agency. Canada has contributed technology, expertise and personnel to the world space effort, especially in collaboration with ESA and NASA. In addition to its astronauts and satellites, some of the most notable Canadian technological contributions to space exploration include the Canadarm on the Space Shuttle and Canadarm2 on the International Space Station.',
#     'administrator': 'President: Lisa Campbell',
#     'founding_year': '1990',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/canadian2520space2520agency_logo_20231122160211.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/chris_hadfield_image_20220911034200.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190208.jpeg',
#    'flights_count': 3,
#    'landings_count': 3,
#    'spacewalks_count': 2,
#    'last_flight': '2012-12-19T12:12:35Z',
#    'first_flight': '1995-11-12T12:30:43Z'},
#   {'id': 6,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/6/',
#    'name': 'David Saint-Jacques',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P203DT12H28M8S',
#    'eva_time': 'PT6H29M',
#    'age': 55,
#    'date_of_birth': '1970-01-06',
#    'date_of_death': None,
#    'nationality': 'Canadian',
#    'bio': 'David Saint-Jacques is a Canadian astronaut with the Canadian Space Agency (CSA).\r\nHe was also an engineer, an astrophysicist, and a physician prior to joining the CSA.\r\nHe was selected to join the CSA in the 2009 CSA selection along with Jeremy Hansen.',
#    'twitter': 'https://twitter.com/Astro_DavidS',
#    'instagram': 'https://www.instagram.com/astrodavids/',
#    'wiki': 'https://en.wikipedia.org/wiki/David_Saint-Jacques',
#    'agency': {'id': 16,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/16/',
#     'name': 'Canadian Space Agency',
#     'featured': False,
#     'type': 'Government',
#     'country_code': 'CAN',
#     'abbrev': 'CSA',
#     'description': 'The Canadian Space Agency was established by the Canadian Space Agency Act which received Royal Assent on May 10, 1990. \r\n\r\nThe Canadian space program is administered by the Canadian Space Agency. Canada has contributed technology, expertise and personnel to the world space effort, especially in collaboration with ESA and NASA. In addition to its astronauts and satellites, some of the most notable Canadian technological contributions to space exploration include the Canadarm on the Space Shuttle and Canadarm2 on the International Space Station.',
#     'administrator': 'President: Lisa Campbell',
#     'founding_year': '1990',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/canadian2520space2520agency_logo_20231122160211.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/david_saint-jac_image_20220911034207.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305191004.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 1,
#    'last_flight': '2018-12-03T11:31:52Z',
#    'first_flight': '2018-12-03T11:31:52Z'},
#   {'id': 7,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/7/',
#    'name': 'Anne McClain',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': True,
#    'time_in_space': 'P297DT15H20M',
#    'eva_time': 'PT18H52M',
#    'age': 46,
#    'date_of_birth': '1979-06-07',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Anne Charlotte McClain is a lieutenant colonel in the U.S. Army currently assigned to NASA Astronaut Group 21.',
#    'twitter': 'https://twitter.com/AstroAnnimal',
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Anne_McClain',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/anne2520mcclain_image_20181127210625.jpg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185442.jpeg',
#    'flights_count': 2,
#    'landings_count': 1,
#    'spacewalks_count': 3,
#    'last_flight': '2025-03-14T23:03:48Z',
#    'first_flight': '2018-12-03T11:31:52Z'},
#   {'id': 8,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/8/',
#    'name': 'Andrew R. Morgan',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P271DT12H48M22S',
#    'eva_time': 'P1DT21H48M',
#    'age': 49,
#    'date_of_birth': '1976-02-05',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Andrew Richard "Drew" Morgan is a NASA astronaut from the class of 2013.',
#    'twitter': 'https://twitter.com/AstroDrewMorgan',
#    'instagram': 'https://www.instagram.com/astrodrewmorgan/',
#    'wiki': 'https://en.wikipedia.org/wiki/Andrew_R._Morgan',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/andrew_r._morga_image_20220911034204.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185549.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 7,
#    'last_flight': '2019-07-20T16:28:21Z',
#    'first_flight': '2019-07-20T16:28:21Z'},
#   {'id': 9,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/9/',
#    'name': 'Nick Hague',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P373DT20H43M16S',
#    'eva_time': 'P1DT1H56M',
#    'age': 49,
#    'date_of_birth': '1975-09-24',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Tyler Nicklaus Hague is an American Flight Test Engineer and a NASA astronaut of the class of 2013.\r\nSelected to be a flight engineer of Expedition 57 / 58 to the International Space Station, he launched on board Soyuz MS-10, which aborted shortly after launch on October 11, 2018.',
#    'twitter': 'https://twitter.com/AstroHague',
#    'instagram': 'https://www.instagram.com/astrohague/',
#    'wiki': 'https://en.wikipedia.org/wiki/Nick_Hague',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/nick_hague_image_20220911034312.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190648.jpeg',
#    'flights_count': 3,
#    'landings_count': 3,
#    'spacewalks_count': 4,
#    'last_flight': '2024-09-28T17:17:21Z',
#    'first_flight': '2018-10-11T08:40:15Z'},
#   {'id': 10,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/10/',
#    'name': 'Terry W. Virts',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P213DT10H50M38S',
#    'eva_time': 'PT19H2M',
#    'age': 57,
#    'date_of_birth': '1967-12-01',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Terry W. Virts Jr. is a former NASA astronaut, and Colonel in the United States Air Force.',
#    'twitter': 'https://twitter.com/AstroTerry',
#    'instagram': 'https://www.instagram.com/astro_terry/',
#    'wiki': 'https://en.wikipedia.org/wiki/Terry_W._Virts',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/terry_w._virts_image_20220911033815.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190900.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 3,
#    'last_flight': '2014-11-23T21:01:14Z',
#    'first_flight': '2010-02-08T09:14:08Z'}]}

# %%
url_total
# Out:
# 'http://ll.thespacedevs.com/2.2.0/astronaut'

# %%
url_total = space_url + path + "/?search=armstrong"
responder = requests.get(url_total)

# %%
url_total
# Out:
# 'http://ll.thespacedevs.com/2.2.0/astronaut/?search=armstrong'

# %%
responder.json()
# Out:
# {'count': 1,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 30,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/30/',
#    'name': 'Neil Armstrong',
#    'status': {'id': 11, 'name': 'Deceased'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P5DT20H50M29S',
#    'eva_time': 'PT2H31M40S',
#    'age': 82,
#    'date_of_birth': '1930-08-05',
#    'date_of_death': '2012-08-25',
#    'nationality': 'American',
#    'bio': 'Neil Alden Armstrong was an American astronaut and aeronautical engineer who was the first person to walk on the Moon. He was also a naval aviator, test pilot, and university professor.',
#    'twitter': None,
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Neil_Armstrong',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/neil2520armstrong_image_20190426143653.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190707.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 1,
#    'last_flight': '1969-07-21T17:54:00Z',
#    'first_flight': '1966-03-16T16:41:02Z'}]}

# %% [markdown]
# ## Accediendo a datos de themoviedb

# %% [markdown]
# Libreria tmdv3api

# %%
#!pip install tmdbv3api
# Out:
# Collecting tmdbv3api
#   Downloading tmdbv3api-1.9.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from tmdbv3api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests->tmdbv3api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests->tmdbv3api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests->tmdbv3api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests->tmdbv3api) (2024.12.14)
# Downloading tmdbv3api-1.9.0-py3-none-any.whl (25 kB)
# Installing collected packages: tmdbv3api
# Successfully installed tmdbv3api-1.9.0

# %%
# https://developers.themoviedb.org/3/getting-started/introduction
from tmdbv3api import TMDb
tmdb = TMDb()
# tmdb.api_key = "pon la tuya"

# %%
from tmdbv3api import Movie

#https://github.com/AnthonyBloomer/tmdbv3api

movie = Movie()

recommendations = movie.recommendations(movie_id=111)

for recommendation in recommendations:
    print(recommendation.title)
    print(recommendation.overview)
# Out:
# Carlito's Way
# Free after years in prison, Carlito Brigante intends to give up his criminal ways, but it's not long before the ex-con is sucked back into the New York City underworld. Reconnecting with his dancer girlfriend, Carlito gets entangled in the shady dealings of his friend Dave Kleinfeld, who also serves as his lawyer. An encounter with shifty gangster Benny Blanco sets the duo on a dangerous path.
# Reservoir Dogs
# A botched robbery indicates a police informant, and the pressure mounts in the aftermath at a warehouse. Crime begets violence as the survivors -- veteran Mr. White, newcomer Mr. Orange, psychopathic parolee Mr. Blonde, bickering weasel Mr. Pink and Nice Guy Eddie -- unravel.
# The Untouchables
# Elliot Ness, an ambitious prohibition agent, is determined to take down Al Capone. In order to achieve this goal, he forms a group given the nickname “The Untouchables”.
# GoodFellas
# The true story of Henry Hill, a half-Irish, half-Sicilian Brooklyn kid who is adopted by neighbourhood gangsters at an early age and climbs the ranks of a Mafia family under the guidance of Jimmy Conway.
# Taxi Driver
# A mentally unstable Vietnam War veteran works as a night-time taxi driver in New York City where the perceived decadence and sleaze feed his urge for violent action.
# Heat
# Obsessive master thief Neil McCauley leads a top-notch crew on various daring heists throughout Los Angeles while determined detective Vincent Hanna pursues him without rest. Each man recognizes and respects the ability and the dedication of the other even though they are aware their cat-and-mouse game may end in violence.
# The Darjeeling Limited
# Three American brothers who have not spoken to each other in a year set off on a train voyage across India with a plan to find themselves and bond with each other -- to become brothers again like they used to be. Their "spiritual quest", however, veers rapidly off-course (due to events involving over-the-counter pain killers, Indian cough syrup, and pepper spray).
# Ferris Bueller's Day Off
# After high school slacker Ferris Bueller successfully fakes an illness in order to skip school for the day, he goes on a series of adventures throughout Chicago with his girlfriend Sloane and best friend Cameron, all the while trying to outwit his wily school principal and fed-up sister.
# V for Vendetta
# In a world in which Great Britain has become a fascist state, a masked vigilante known only as “V” conducts guerrilla warfare against the oppressive British government. When V rescues a young woman from the secret police, he finds in her an ally with whom he can continue his fight to free the people of Britain.
# Apocalypse Now
# At the height of the Vietnam war, Captain Benjamin Willard is sent on a dangerous mission that, officially, "does not exist, nor will it ever exist." His goal is to locate - and eliminate - a mysterious Green Beret Colonel named Walter Kurtz, who has been leading his personal army on illegal guerrilla missions into enemy territory.
# The Departed
# To take down South Boston's Irish Mafia, the police send in one of their own to infiltrate the underworld, not realizing the syndicate has done likewise. While an undercover cop curries favor with the mob kingpin, a career criminal rises through the police ranks. But both sides soon discover there's a mole among them.
# Vertigo
# A retired San Francisco detective suffering from acrophobia investigates the strange activities of an old friend's wife, all the while becoming dangerously obsessed with her.
# Donnie Brasco
# An FBI undercover agent infiltrates the mob and identifies more with the mafia life at the expense of his regular one.
# The Godfather
# Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.
# Friday the 13th
# Camp counselors are stalked and murdered by an unknown assailant while trying to reopen a summer camp that was the site of a child's drowning.
# The Godfather Part II
# In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.
# Dog Day Afternoon
# Based on the true story of would-be Brooklyn bank robbers John Wojtowicz and Salvatore Naturile. Sonny and Sal attempt a bank heist which quickly turns sour and escalates into a hostage situation and stand-off with the police. As Sonny's motives for the robbery are slowly revealed and things become more complicated, the heist turns into a media circus.
# Death at a Funeral
# A myriad of outrageous calamities befalls an eccentric English clan with more than a few skeletons in its closets when the family's patriarch dies an unexpected death.
# Angel Heart
# A down-and-out Brooklyn detective is hired to track down a singer on an odyssey that will take him through the desperate streets of Harlem, the smoke-filled jazz clubs of New Orleans, and the swamps of Louisiana and its seedy underworld of voodoo.
# Scarface
# In 1920s Chicago, Italian immigrant and notorious thug, Antonio 'Tony' Camonte, aka Scarface, shoots his way to the top of the mobs while trying to protect his sister from the criminal life.

# %%
movie = Movie()
popular = movie.popular()

for p in popular:
    print(p.id)
    print(p.title)
    print(p.overview)
    print(p.poster_path)
# Out:
# 574475
# Final Destination Bloodlines
# Plagued by a violent recurring nightmare, college student Stefanie heads home to track down the one person who might be able to break the cycle and save her family from the grisly demise that inevitably awaits them all.
# /6WxhEvFsauuACfv8HyoVX6mZKFj.jpg
# 1087891
# The Amateur
# After his life is turned upside down when his wife is killed in a London terrorist attack, a brilliant but introverted CIA decoder takes matters into his own hands when his supervisors refuse to take action.
# /SNEoUInCa5fAgwuEBMIMBGvkkh.jpg
# 1426776
# STRAW
# What will be her last straw? A devastatingly bad day pushes a hardworking single mother to the breaking point — and into a shocking act of desperation.
# /t3cmnXYtxJb9vVL1ThvT2CWSe1n.jpg
# 1376434
# Predator: Killer of Killers
# While three of the fiercest warriors in human history—a Viking raider, a ninja in feudal Japan, and a WWII pilot—are killers in their own right, they are merely prey for their new opponent: the ultimate killer of killers.
# /2XDQa6EmFHSA37j1t0w88vpWqj9.jpg
# 552524
# Lilo & Stitch
# The wildly funny and touching story of a lonely Hawaiian girl and the fugitive alien who helps to mend her broken family.
# /A89x10Eqt43bPFEWPpbraWwkaFr.jpg
# 870028
# The Accountant²
# When an old acquaintance is murdered, Wolff is compelled to solve the case. Realizing more extreme measures are necessary, Wolff recruits his estranged and highly lethal brother, Brax, to help. In partnership with Marybeth Medina, they uncover a deadly conspiracy, becoming targets of a ruthless network of killers who will stop at nothing to keep their secrets buried.
# /kMDUS7VmFhb2coRfVBoGLR8ADBt.jpg
# 1087192
# How to Train Your Dragon
# On the rugged isle of Berk, where Vikings and dragons have been bitter enemies for generations, Hiccup stands apart, defying centuries of tradition when he befriends Toothless, a feared Night Fury dragon. Their unlikely bond reveals the true nature of dragons, challenging the very foundations of Viking society.
# /q5pXRYTycaeW6dEgsCrd4mYPmxM.jpg
# 1379587
# Utopia
# A soldier searching for his missing wife breaks into a high-tech facility, believing she's been caught in a human trafficking ring. But beyond its walls, he finds a surreal, futuristic fantasy park where reality and illusion blur. As he navigates this seductive and dangerous world, a shocking truth pulls him deeper into a deadly game where nothing is as it seems.
# /yef0tY1Nw3BX8PJTfBLieqHj5Hw.jpg
# 1315988
# Mikaela
# During the eve of the 6th of January, a record-breaking snowstorm sweeps across Spain. In the midst of its chaos, a group of robbers seizes the opportunity to hijack an armoured van. A few meters away is Leo, a finished policeman who has nothing to lose. With the unexpected aid of a young woman, he will try to stop the band from running away with their loot.
# /xG8olkWOmoW78GbozKbS2UxYGEo.jpg
# 1450599
# K.O.
# A former fighter must find the missing son of an opponent he accidentally killed years ago, taking on a brutally violent crime gang in Marseille.
# /qcM2sUiAeP4zXwx4ADSvgc9S58k.jpg
# 1239193
# Deep Cover
# Kat is an improv comedy teacher beginning to question if she’s missed her shot at success. When an undercover cop offers her the role of a lifetime, she recruits two of her students to infiltrate London’s gangland by impersonating dangerous criminals.
# /euM8fJvfH28xhjGy25LiygxfkWc.jpg
# 1225916
# 3ão: An Endless Story
# This movie is a gift for the 2023 ESCA high school third-year students. Despite a challenging year, we know it wasn't all about studying and sadness...
# /ghNV52iBTQgtkd0nFZkAyvngCbr.jpg
# 713364
# Clown in a Cornfield
# Quinn and her father have just moved to the quiet town of Kettle Springs hoping for a fresh start. Instead, she discovers a fractured community that has fallen on hard times after the treasured Baypen Corn Syrup Factory burned down. As the locals bicker amongst themselves and tensions boil over, a sinister, grinning figure emerges from the cornfields to cleanse the town of its burdens, one bloody victim at a time.
# /6ep6gw90TJ8bYvJC6hEDo8SxjoJ.jpg
# 1233413
# Sinners
# Trying to leave their troubled lives behind, twin brothers return to their hometown to start again, only to discover that an even greater evil is waiting to welcome them back.
# /zrYk9fEhhnNTptnhFeyyFIUBu5d.jpg
# 1017163
# The Roundup: Punishment
# 'Monster Cop' Ma Seok-do investigates an illegal online gambling business led by a former STS Baek and an IT genius CEO Chang. Ma proposes an unexpected alliance to Jang and begins hunting down the criminals.
# /yk38mNoJpsswmk9o7i7eLhO4mc.jpg
# 1289601
# Life After Fighting
# Retired martial arts world champion Alex Faulkner has settled into a simple life, when the disappearance of two of his students leads to an unthinkable discovery close to home. Just when all hope of finding the children is lost, he locates the imprisoned girls and unsurfaces an international child trafficking operation, which draws him back into the fight of his life against those behind it.
# /uKWAk4BHzyEOMmLKUDXoIAPhH36.jpg
# 666154
# Kayara
# A courageous and athletic teenager, Kayara dreams that she is destined to be the first female to break into the league of Chasquis - the official messengers of the Incan empire. As she learns what it takes to be a Chasqui along with its challenges, she tackles every mission she gets and discovers the ancient stories of her land and her people.
# /tpZdjnoJ6Z3NsSxI6HjAIggrcEv.jpg
# 950387
# A Minecraft Movie
# Four misfits find themselves struggling with ordinary problems when they are suddenly pulled through a mysterious portal into the Overworld: a bizarre, cubic wonderland that thrives on imagination. To get back home, they'll have to master this world while embarking on a magical quest with an unexpected, expert crafter, Steve.
# /yFHHfHcUgGAxziP1C3lLt0q2T4s.jpg
# 1240475
# Hunt the Wicked
# The film tells the story of narcotics police officer Huang Mingjin and the "mysterious figure" Wei Yunzhou. Through completely different means and methods, in the process of calculating and wrestling with each other, they tear apart the facade of urban tranquility, exposing the underground drug network woven by the hidden hand "Long Wang", and ultimately eradicate the darkness with the sword of justice, revealing the dawn of light.
# /m5UBHbEjQJx3AkRZWRY6A4l4ZDT.jpg
# 541671
# Ballerina
# Taking place during the events of John Wick: Chapter 3 – Parabellum, Eve Macarro begins her training in the assassin traditions of the Ruska Roma.
# /mKp4euM5Cv3m2U1Vmby3OGwcD5y.jpg

# %%
import requests
response = requests.get("https://api.themoviedb.org/3/discover/movie?api_key=<<api_key>>&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&page=2&primary_release_year=2010")

# %%
response.json()
# Out:
# {'status_code': 7,
#  'status_message': 'Invalid API key: You must be granted a valid key.',
#  'success': False}

# %% [markdown]
# #### Acceder a datos de la api desde la URL con la libreria requests

# %%
import numpy as np
import pandas as pd

# https://www.themoviedb.org/documentation/api
api_key = "pon la tuya"

years = np.arange(2020, 2021)
id_movies = []
release_date = []
title = []
for i in years:
    print("year:", i )
    for j in range(1,5): 
        response = requests.get(f'https://api.themoviedb.org/3/discover/movie?api_key={api_key}&page={j}&primary_release_year={i}&sort_by=popularity.desc')
        highest_revenue = response.json()
        print(highest_revenue)
        
        first_results = highest_revenue["results"]
       
        for k in first_results:
                     
            try:                
                release_date.append(k["release_date"])
                title.append(k["title"])
                id_movies.append(k["id"])  
            except:
                release_date.append(np.nan)
                title.append(np.nan)
                id_movies.append(np.nan)
                continue

df_movies_id = pd.DataFrame(id_movies, columns=["id"])
df_movies_id["date"] = release_date
df_movies_id["title"] = title
# Out:
# year: 2020
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/54mPXhtaUejdQtaCYeJPJP8ZfXX.jpg', 'genre_ids': [18, 10749], 'id': 715287, 'original_language': 'ko', 'original_title': '새엄마의 욕망', 'overview': "Sang-jin, who was envious of her neighbor after getting a beautiful wife, Ask your wife's friend Gian to take over the son's extracurricular teacher, Sang-jin, who left work early, accidentally sees Gian's shower. A man who wants to have sex with his son's tutor, And a son who wants to have a good time with a young stepmom, Ji-an and Jin-hee, who want money, are disappointed with her husband, and Bin-jin gives her body to a young son.", 'popularity': 61.363, 'poster_path': '/rYC6UyML4CU4zYiZVbDMrwnGyWW.jpg', 'release_date': '2020-05-29', 'title': "Stepmom's Desire", 'video': False, 'vote_average': 7.15, 'vote_count': 20}, {'adult': False, 'backdrop_path': '/ruqcHnXZvszzPB4dvDuQI7DT7Wd.jpg', 'genre_ids': [10749], 'id': 694943, 'original_language': 'ko', 'original_title': '배달노출: 알몸으로 유혹하기', 'overview': 'Seok, who wants to try perverted sex, pesters Hyun-jin every day, but Hyun-jin rejects it saying she only like normal things.  And then one day while delivering chicken, he found So-ra and Hyun-soo, a couple who enjoys delivery exposures.  Frustrated as he is with Hyun-jin, he starts neglecting her and became more and more hooked with the So-ra couple.  To recover their relationship, Hyun-jin goes on a date with Seok. But then a call came for him. The couple invites him for sex.  Will he be having a date with his wife, or will he accept the invitation he may only get once in a lifetime?  What would be his choice?', 'popularity': 21.5666, 'poster_path': '/km7xKnZoHUXqiozCGzauunMp9OF.jpg', 'release_date': '2020-04-10', 'title': 'Pizza Dare 1', 'video': False, 'vote_average': 6.222, 'vote_count': 9}, {'adult': False, 'backdrop_path': '/g4j7H4yDoCR90X1VV2IEvAZ1LAP.jpg', 'genre_ids': [18, 10749], 'id': 707610, 'original_language': 'ko', 'original_title': '가슴 큰 울 엄마', 'overview': "Da-hee gets married to Min-soo who is older than her. Thanks to him, he also gets a son who is not too old, Jae-hyuk, who she tries to get acquainted with, albeit awkwardly. After staying with Na-yeon, she suddenly has to meet Jae-hyuk, and Na-yeon has a date with Jae-hyuk. Min-soo is surprised to find three people coming back home from a date. It made him angry to see his son with two women. Right away, Min-soo seeks Da-hee and asks about Na-yeon. Na-yeon met Min-soo secretly. However, Da-hee who is aware of Min-soo and Da-hee's relationship, shares this fact to Jae-hyun.", 'popularity': 14.5177, 'poster_path': '/zarhMAQRWKjjsNBR1rviIXZ5xtt.jpg', 'release_date': '2020-05-06', 'title': 'Bosomy Mom', 'video': False, 'vote_average': 5.9, 'vote_count': 11}, {'adult': False, 'backdrop_path': '/stmYfCUGd8Iy6kAMBr6AmWqx8Bq.jpg', 'genre_ids': [28, 878, 35, 10751], 'id': 454626, 'original_language': 'en', 'original_title': 'Sonic the Hedgehog', 'overview': 'Powered with incredible speed, Sonic The Hedgehog embraces his new home on Earth. That is, until Sonic sparks the attention of super-uncool evil genius Dr. Robotnik. Now it’s super-villain vs. super-sonic in an all-out race across the globe to stop Robotnik from using Sonic’s unique power for world domination.', 'popularity': 14.2546, 'poster_path': '/aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg', 'release_date': '2020-02-12', 'title': 'Sonic the Hedgehog', 'video': False, 'vote_average': 7.307, 'vote_count': 9955}, {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 739187, 'original_language': 'ar', 'original_title': '12', 'overview': 'not there yet', 'popularity': 12.83, 'poster_path': '/kCnwPVGf7zHW2iLSgbvKDLl8m4Q.jpg', 'release_date': '2020-09-04', 'title': '12', 'video': False, 'vote_average': 5.481, 'vote_count': 53}, {'adult': False, 'backdrop_path': '/3FVe3OAdgz060JaxIAaUl5lo6cx.jpg', 'genre_ids': [16, 28, 14, 53], 'id': 635302, 'original_language': 'ja', 'original_title': '劇場版「鬼滅の刃」無限列車編', 'overview': "Tanj ...
# {'page': 2, 'results': [{'adult': False, 'backdrop_path': '/gEjNlhZhyHeto6Fy5wWy5Uk3A9D.jpg', 'genre_ids': [27, 28, 53, 12], 'id': 581392, 'original_language': 'ko', 'original_title': '반도', 'overview': 'A soldier and his team battle hordes of post-apocalyptic zombies in the wastelands of the Korean Peninsula.', 'popularity': 6.7951, 'poster_path': '/eeqvAzCccAZOhU3RfbvHB3s44S6.jpg', 'release_date': '2020-07-15', 'title': 'Peninsula', 'video': False, 'vote_average': 6.742, 'vote_count': 2424}, {'adult': False, 'backdrop_path': '/7KR1nKGaYqPuFBnqP7XBIX0DZlR.jpg', 'genre_ids': [18, 10751], 'id': 770156, 'original_language': 'en', 'original_title': 'Lucy Shimmers and the Prince of Peace', 'overview': 'Second chances start when a hardened criminal crosses paths with a precocious little girl who is helped by an angel to change hearts during the holiday season.', 'popularity': 7.1898, 'poster_path': '/yfnJ5qIYx7q33fY4jqv9Pu95RSg.jpg', 'release_date': '2020-10-19', 'title': 'Lucy Shimmers and the Prince of Peace', 'video': False, 'vote_average': 8.355, 'vote_count': 310}, {'adult': False, 'backdrop_path': None, 'genre_ids': [99], 'id': 737043, 'original_language': 'en', 'original_title': 'Swingers', 'overview': "Observational documentary unlocking the doors of Britain's hidden swinging scene via access to one of the country's most popular swinging clubs and candid interviews with the club's founder, staff and clientele.", 'popularity': 5.4848, 'poster_path': '/z4uwQVm0Th3lngECVZvMHVaaFur.jpg', 'release_date': '2020-08-24', 'title': 'Swingers', 'video': False, 'vote_average': 4.5, 'vote_count': 2}, {'adult': False, 'backdrop_path': '/oubeM1HVaEpS1fk0L2qf12xWFR6.jpg', 'genre_ids': [18, 10749], 'id': 784941, 'original_language': 'ko', 'original_title': '처제 길들이기', 'overview': "One day, Min-sang who is not that handsome becomes a huge success because of a webtoon. Then he gets a sexy wife, Yu-ra, for himself. Min-sang is having a dream-like marriage with Yura. It has been a perfect day except for his sister-in-law Yu-mi, who hates her ugly self. Accidentally, he learned of his wife's dark past through his sister-in-law's diary, and this leads to a reversal of the relationship with her sister-in-law. Min-sang began to demand excessive demands from his sister-in-law, and Yu-mi began to accept them. Where will the end of the relationship between Min-sang, Yu-ra, and Yu-mi lead?", 'popularity': 6.8246, 'poster_path': '/dF5SiTe94NkkGJNinB6Mz2izKy0.jpg', 'release_date': '2020-12-11', 'title': 'Taming The Younger Sister-in-Law', 'video': False, 'vote_average': 5.7, 'vote_count': 9}, {'adult': False, 'backdrop_path': '/lVbPO7RjsMWoUwH1ISRbZNbg62s.jpg', 'genre_ids': [27, 35], 'id': 551804, 'original_language': 'en', 'original_title': 'Freaky', 'overview': 'A mystical, ancient dagger causes a notorious serial killer to magically switch bodies with a 17-year-old girl.', 'popularity': 5.1074, 'poster_path': '/8xC6QSyxrpm0D5A6iyHNemEWBVe.jpg', 'release_date': '2020-11-12', 'title': 'Freaky', 'video': False, 'vote_average': 6.562, 'vote_count': 1692}, {'adult': False, 'backdrop_path': '/pQQggUuDMleFSl2tQYxzTmKIiLU.jpg', 'genre_ids': [12, 9648, 80], 'id': 497582, 'original_language': 'en', 'original_title': 'Enola Holmes', 'overview': 'While searching for her missing mother, intrepid teen Enola Holmes uses her sleuthing skills to outsmart big brother Sherlock and help a runaway lord.', 'popularity': 6.0405, 'poster_path': '/riYInlsq2kf1AWoGm80JQW5dLKp.jpg', 'release_date': '2020-09-23', 'title': 'Enola Holmes', 'video': False, 'vote_average': 7.254, 'vote_count': 6200}, {'adult': False, 'backdrop_path': None, 'genre_ids': [10749], 'id': 689160, 'original_language': 'ko', 'original_title': '맛있는 과외누나', 'overview': 'Bong-soo receives a love tutor from Hope to escape from Moto-solo. Just a friend, Jeongyeon, starts to look like a woman. Bongsu confesses his anxiety to hope.', 'popularity': 6.3799, 'poster_path': '/hqRAWy3EwIeDOoWU2gL1LU5VQw7.jpg', 'release_d ...
# {'page': 3, 'results': [{'adult': False, 'backdrop_path': '/vawcE8k02PmvrAgZE4BuwOcf6Hs.jpg', 'genre_ids': [10749], 'id': 711978, 'original_language': 'ko', 'original_title': '가슴 큰 울 엄마 2', 'overview': "Min-soo and Jae-hyeok is in a good father-and-son relationship. But one day, Min-soo brings Jae-hyeok's young stepmother, Da-hee. Jae-hyeok leaves home to wander around, ran into Da-hee's friend, Na-yeon, and had a little talk. Na-yeon calls Da-hee... Da-hee goes home with Jae-hyeok, and Min-soo doesn't care much. Jae-hyeok tells Da-hee how he feels. Meanwhile, Min-soo who disapproves Da-hee and Jae-hyeok's relationship, calls Na-yeon to kill some time. And Na-yeon who is worried about Da-hee and Min-soo crafts a new plan...", 'popularity': 5.4938, 'poster_path': '/3qotZafIXzrgq7SUmHsBY6onRcU.jpg', 'release_date': '2020-05-27', 'title': 'Bosomy Mom 2', 'video': False, 'vote_average': 5.0, 'vote_count': 6}, {'adult': False, 'backdrop_path': '/1GZCV0dwIoAn6jpWPfVAbeMTVC2.jpg', 'genre_ids': [12, 10751, 18], 'id': 481848, 'original_language': 'en', 'original_title': 'The Call of the Wild', 'overview': 'Buck is a big-hearted dog whose blissful domestic life is turned upside down when he is suddenly uprooted from his California home and transplanted to the exotic wilds of the Yukon during the Gold Rush of the 1890s. As the newest rookie on a mail delivery dog sled team—and later its leader—Buck experiences the adventure of a lifetime, ultimately finding his true place in the world and becoming his own master.', 'popularity': 5.4862, 'poster_path': '/33VdppGbeNxICrFUtW2WpGHvfYc.jpg', 'release_date': '2020-02-19', 'title': 'The Call of the Wild', 'video': False, 'vote_average': 7.54, 'vote_count': 3809}, {'adult': False, 'backdrop_path': '/uWVkEo9PWHu9algZsiLPi6sRU64.jpg', 'genre_ids': [36, 18], 'id': 556574, 'original_language': 'en', 'original_title': 'Hamilton', 'overview': 'Presenting the tale of American founding father Alexander Hamilton, this filmed version of the original Broadway smash hit is the story of America then, told by America now.', 'popularity': 5.0882, 'poster_path': '/h1B7tW0t399VDjAcWJh8m87469b.jpg', 'release_date': '2020-07-03', 'title': 'Hamilton', 'video': False, 'vote_average': 8.141, 'vote_count': 1501}, {'adult': False, 'backdrop_path': '/2OVYqRg0RShzWCNO8TbqShuQZYB.jpg', 'genre_ids': [18], 'id': 865010, 'original_language': 'en', 'original_title': 'Titoudao', 'overview': "From a poor village girl to a famous wayang (Chinese Opera) star, Titoudao chronicles the colourful and turbulent life of celebrated wayang star Oon Ah Chiam. Born into a poor family of 12 children, Ah Chiam's father was always trying to get rid of her. She had to constantly prove herself in order to fight for chance to stay in the family. Fate brought her and her sister Ah Dui into the famous Sin Sai Hong wayang troupe. There she rose through the ranks through hard work and grit to become their top star. But not before she had to protect her sister from a lecherous trainer and fight off a scheming competitor Ah Ngor. And will she find love with the troupe master's son Ah Zai or a pushcart hawker Ah hock?", 'popularity': 5.4319, 'poster_path': '/8D0lNWGpsjzyPTwefB6GxqD3Inb.jpg', 'release_date': '2020-02-11', 'title': 'Titoudao', 'video': False, 'vote_average': 8.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/5UkzNSOK561c2QRy2Zr4AkADzLT.jpg', 'genre_ids': [878], 'id': 528085, 'original_language': 'en', 'original_title': '2067', 'overview': 'A lowly utility worker is called to the future by a mysterious radio signal, he must leave his dying wife to embark on a journey that will force him to face his deepest fears in an attempt to change the fabric of reality and save humankind from its greatest environmental crisis yet.', 'popularity': 6.1867, 'poster_path': '/7D430eqZj8y3oVkLFfsWXGRcpEG.jpg', 'release_date': '2020-10-01', 'title': '2067', 'video': False, 'vote_average': 5.362, 'vote_count': 863}, {'adult': False, 'backdrop_path':  ...
# {'page': 4, 'results': [{'adult': False, 'backdrop_path': '/rWrvcsrvISKXdMOzCdkvU3Jtg0j.jpg', 'genre_ids': [53, 80, 18], 'id': 582014, 'original_language': 'en', 'original_title': 'Promising Young Woman', 'overview': 'A young woman, traumatized by a tragic event in her past, seeks out vengeance against those who crossed her path.', 'popularity': 5.0135, 'poster_path': '/73QoFJFmUrJfDG2EynFjNc5gJxk.jpg', 'release_date': '2020-12-13', 'title': 'Promising Young Woman', 'video': False, 'vote_average': 7.419, 'vote_count': 3378}, {'adult': False, 'backdrop_path': '/2BZ7PC9aISswNXV2tugmjGiriaB.jpg', 'genre_ids': [16, 10770, 14, 28], 'id': 755812, 'original_language': 'fr', 'original_title': 'Miraculous World : New York, les héros unis', 'overview': 'Marinette’s class is headed to New York, the city of superheroes, for French-American Friendship Week. The whole class is there...except Adrien, whose father refuses to let him go!', 'popularity': 3.9677, 'poster_path': '/9YbyvcrHmY2SVbdfXpb8mC4Fy0g.jpg', 'release_date': '2020-09-25', 'title': 'Miraculous World: New York, United HeroeZ', 'video': False, 'vote_average': 8.088, 'vote_count': 1113}, {'adult': False, 'backdrop_path': '/hwpbTeZEaKKUfiUjc2FJZpv7uAI.jpg', 'genre_ids': [27, 9648, 53], 'id': 516632, 'original_language': 'en', 'original_title': 'The Empty Man', 'overview': 'Retired cop James Lasombra is asked by a friend to investigate the disappearance of her daughter, who seemingly packed in the night and left an ominous message on the bathroom mirror - "The Empty Man Made Me Do It." As he investigates this mysterious figure further, James begins to see and hear strange things, and is forced to come to terms with his past and what it means for his future.', 'popularity': 4.8433, 'poster_path': '/8apzu9JFTUMtOpYkHk6LNPOs3pY.jpg', 'release_date': '2020-10-22', 'title': 'The Empty Man', 'video': False, 'vote_average': 6.172, 'vote_count': 899}, {'adult': False, 'backdrop_path': '/xcUf6yIheo78btFqihlRLftdR3M.jpg', 'genre_ids': [10751, 35, 14, 12], 'id': 448119, 'original_language': 'en', 'original_title': 'Dolittle', 'overview': 'After losing his wife seven years earlier, the eccentric Dr. John Dolittle, famed doctor and veterinarian of Queen Victoria’s England, hermits himself away behind the high walls of Dolittle Manor with only his menagerie of exotic animals for company. But when the young queen falls gravely ill, a reluctant Dolittle is forced to set sail on an epic adventure to a mythical island in search of a cure, regaining his wit and courage as he crosses old adversaries and discovers wondrous creatures.', 'popularity': 4.4429, 'poster_path': '/uoplwswBDy7gsOyrbGuKyPFoPCs.jpg', 'release_date': '2020-01-02', 'title': 'Dolittle', 'video': False, 'vote_average': 6.598, 'vote_count': 3694}, {'adult': False, 'backdrop_path': '/rLchzndbDRy41J9X363pMePbV5x.jpg', 'genre_ids': [53, 27, 18], 'id': 546121, 'original_language': 'en', 'original_title': 'Run', 'overview': 'Chloe, a teenager who is confined to a wheelchair, is homeschooled by her mother, Diane. Chloe soon becomes suspicious of her mother and begins to suspect that she may be harboring a dark secret.', 'popularity': 4.4352, 'poster_path': '/ilHG4EayOVoYeKqslspY3pR4wzC.jpg', 'release_date': '2020-11-20', 'title': 'Run', 'video': False, 'vote_average': 7.242, 'vote_count': 2664}, {'adult': False, 'backdrop_path': '/bXdCpL1A1mW2sEBiTmYYFnb10XN.jpg', 'genre_ids': [35, 10749], 'id': 583083, 'original_language': 'en', 'original_title': 'The Kissing Booth 2', 'overview': 'With college decisions looming, Elle juggles her long-distance romance with Noah, changing relationship with bestie Lee and feelings for a new classmate.', 'popularity': 4.5646, 'poster_path': '/mb7wQv0adK3kjOUr9n93mANHhPJ.jpg', 'release_date': '2020-07-24', 'title': 'The Kissing Booth 2', 'video': False, 'vote_average': 7.628, 'vote_count': 5041}, {'adult': False, 'backdrop_path': '/dNkHXrftLNlGwCaljQeM1hCOLjn.jpg', 'genre_ids': [28, 878, 12], 'id': 338762, ' ...

# %%
df_movies_id
# Out:
#         id        date                         title
# 0   715287  2020-05-29              Stepmom's Desire
# 1   694943  2020-04-10                  Pizza Dare 1
# 2   707610  2020-05-06                    Bosomy Mom
# 3   454626  2020-02-12            Sonic the Hedgehog
# 4   739187  2020-09-04                            12
# ..     ...         ...                           ...
# 75  533514  2020-09-18  Violet Evergarden: The Movie
# 76  443791  2020-01-08                    Underwater
# 77  647785  2020-05-29               Debt Collectors
# 78  509635  2020-09-10                         Alone
# 79  556678  2020-02-13                         Emma.
#
# [80 rows x 3 columns]

# %%
df_movies_id["id"].values
# Out:
# array([715287, 694943, 707610, 454626, 739187, 635302, 508442, 613504,
#        529203, 464052, 587792, 577922,  38700, 337401, 545609, 516486,
#        522627, 664413, 514593, 614696, 581392, 770156, 737043, 784941,
#        551804, 497582, 689160, 446893, 660982, 590223, 495764, 524047,
#        514207, 531219, 400160, 514847, 600354, 615677, 627725, 508439,
#        711978, 481848, 556574, 865010, 528085, 740985, 702936, 713607,
#        340102, 602147, 665251, 547016, 667520, 570670, 664767, 458576,
#        575604, 719128, 580175, 604822, 582014, 755812, 516632, 448119,
#        546121, 583083, 338762, 447362, 652837, 693158, 723072, 708981,
#        740903, 430155, 531876, 533514, 443791, 647785, 509635, 556678])

# %%
dict_movies = {"title":[], "revenue":[], "budget":[]}
for q in df_movies_id["id"].values[:11]:
    response = requests.get(f'https://api.themoviedb.org/3/movie/{q}?api_key=' +  api_key + "&append_to_response=keywords,credits")
    highest_revenue = response.json()
    try:
        budget = highest_revenue["budget"]
        revenue = highest_revenue["revenue"]
        title = highest_revenue['title']
        dict_movies["title"].append(title)
        dict_movies["revenue"].append(revenue)
        dict_movies["budget"].append(budget)
    except:
        continue
df_movies_2010 = pd.DataFrame(dict_movies)

# %%
df_movies_2010
# Out:
#                                                 title    revenue     budget
# 0                                    Stepmom's Desire          0          0
# 1                                        Pizza Dare 1          0          0
# 2                                          Bosomy Mom          0          0
# 3                                  Sonic the Hedgehog  319715683   85000000
# 4                                                  12          0          0
# 5   Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...  523542183   15700000
# 6                                                Soul  121977511  150000000
# 7                                   After We Collided   47990414   14000000
# 8                               The Croods: A New Age  215905815   65000000
# 9                                   Wonder Woman 1984  169601036  200000000
# 10                                       Palm Springs    1818417    5000000

# %%
df_movies_2010.to_csv("data/df_movies_2010.csv")

# %%
df_movies_id.head()
# Out:
#        id        date               title
# 0  715287  2020-05-29    Stepmom's Desire
# 1  694943  2020-04-10        Pizza Dare 1
# 2  707610  2020-05-06          Bosomy Mom
# 3  454626  2020-02-12  Sonic the Hedgehog
# 4  739187  2020-09-04                  12

# %% [markdown]
# ## Accediendo a datos de Youtube

# %%
# !pip install google-api-python-client
# Out:
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.172.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client)
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 (from google-api-python-client)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client)
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client)
#   Downloading google_api_core-2.25.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Downloading uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Using cached googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.3)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2024.12.14)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading google_api_python_client-2.172.0-py3-none-any.whl (13.6 MB)
#    ---------------------------------------- 0.0/13.6 MB ? eta -:--:--
#    --------------- ------------------------ 5.2/13.6 MB 27.4 MB/s eta 0:00:01
#    --------------------------------- ------ 11.5/13.6 MB 29.0 MB/s eta 0:00:01
#    ---------------------------------------- 13.6/13.6 MB 26.0 MB/s eta 0:00:00
# Downloading google_api_core-2.25.1-py3-none-any.whl (160 kB)
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Using cached googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl (435 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Installing collected packages: uritemplate, pyasn1, protobuf, httplib2, cachetools, rsa, pyasn1-modules, proto-plus, googleapis-common-protos, google-auth, google-auth-httplib2, google-api-core, google-api-python-client
#
#    --- ------------------------------------  1/13 [pyasn1]
#    --- ------------------------------------  1/13 [pyasn1]
#    --- ------------------------------------  1/13 [pyasn1]
#    --- ------------------------------------  1/13 [pyasn1]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    ------ ---------------------------------  2/13 [protobuf]
#    --------- ------------------------------  3/13 [httplib2]
#    ------------ ---------------------------  4/13 [cachetools]
#    --------------- ------------------------  5/13 [rsa]
#    --------------- ------------------------  5/13 [rsa]
#    --------------- ------------------------  5/13 [rsa]
#    --------------- ------------------------  5/13 [rsa]
#    --------------- ------------------------  5/13 [rsa]
#    --------------- ------------------------  5/13 [rsa]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    ------------------ ---------------------  6/13 [pyasn1-modules]
#    --------------------- ------------------  7/13 [proto-plus]
#    --------------------- ------------------  7/13 [proto-plus]
#    ------------------------ ---------------  8/13 [googleapis-common-protos]
#    ------------------------ ---------------  8/13 [googleapis-common-protos]
#    ------------------------ ---------------  8/13 [googleapis-common-protos]
#    ------------------------ ---------------  8/13 [googleapis-common-protos]
#    ------------------------ ---------------  8/13 [googleapis-common-protos]
#    ------------------------ ---------------  8/13 [googleapis-common-protos]
#    ------------------------ ---------------  8/13 [googleapis-common-protos]
#    ------------------------ ---------------  8/13 [googleapis-common-protos]
#    ------------------------ ---------------  8/13 [googleapis-common-protos]
#    ------------------------ ---------------  8/13 [googleapis-common-protos]
#    ------------------------ ---------------  8/13 [googleapis-common-protos]
#    --------------------------- ------------  9/13 [google-auth]
#    --------------------------- ------------  9/13 [google-auth]
#    --------------------------- ------------  9/13 [google-auth]
#    --------------------------- ------------  9/13 [google-auth]
#    --------------------------- ------------  9/13 [google-auth]
#    --------------------------- ------------  9/13 [google-auth]
#    --------------------------- ------------  9/13 [google-auth]
#    --------------------------- ------------  9/13 [google-auth]
#    ------------------------------ --------- 10/13 [google-auth-httplib2]
#    --------------------------------- ------ 11/13 [google-api-core]
#    --------------------------------- ------ 11/13 [google-api-core]
#    --------------------------------- ------ 11/13 [google-api-core]
#    --------------------------------- ------ 11/13 [google-api-core]
#    --------------------------------- ------ 11/13 [google-api-core]
#    --------------------------------- ------ 11/13 [google-api-core]
#    ------------------------------------ --- 12/13 [google-api-python-client]
#    ------------------------------------ --- 12/13 [google-api-python-client]
#    ------------------------------------ --- 12/13 [google-api-python-client]
#    ------------------------------------ --- 12/13 [google-api-python-client]
#    ------------------------------------ --- 12/13 [google-api-python-client]
#    ------------------------------------ --- 12/13 [google-api-python-client]
#    ---------------------------------------- 13/13 [google-api-python-client]
#
# Successfully installed cachetools-5.5.2 google-api-core-2.25.1 google-api-python-client-2.172.0 google-auth-2.40.3 google-auth-httplib2-0.2.0 googleapis-common-protos-1.70.0 httplib2-0.22.0 proto-plus-1.26.1 protobuf-6.31.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1 uritemplate-4.2.0

# %%
# Importamos librerías

from googleapiclient.discovery import build

# %% [markdown]
# ### Información de una Canal de youtube (Primera request)

# %% [markdown]
# You may be watching the video or just happened to visit a link to a video.
#
# The video ID will be located in the URL of the video page, right after the v= URL parameter.
#
# In this case, the URL of the video is: https://www.youtube.com/watch?v=fn3KWM1kuAw. Therefore, the ID of the video is fn3KWM1kuAw

# %%
#   https://cloud.google.com/console para crear proyecto y habilitar la api de youtube v3
#   https://github.com/googleapis/google-api-python-client documentacion de la api de youtube
# Para mas informacion de las diferentes busquedas de datos disponibles como sus parametros ir a https://developers.google.com/youtube/v3/getting-started?hl=es-419
# Ensure that you have enabled the YouTube Data API for your project.
api_key_y = "pon tu api key"

youtube = build("youtube", "v3", developerKey=api_key_y)


request = youtube.channels().list(
    part="statistics",
    id = "UCy5znSnfMsDwaLlROnZ7Qbg"
)

response = request.execute()

# %%
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'pdsexKyZor6x1pLqQXS0gFplYRA',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '63MxrLgzhSqrU1JJ0IaSeuiVf1A',
#    'id': 'UCy5znSnfMsDwaLlROnZ7Qbg',
#    'statistics': {'viewCount': '54112241',
#     'subscriberCount': '897000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '228'}}]}

# %% [markdown]
# ### Información videos de acuerdo a una búsqueda (query)

# %%
search_response = youtube.search().list(
    q="Chat gpt",
    part="snippet",
    order="viewCount",
    type="video",
    maxResults=50
).execute()

# %%
search_response["items"][0]["snippet"]
# Out:
# {'publishedAt': '2024-01-11T14:36:20Z',
#  'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#  'title': 'ChatGPT, Show Me Chicken Nuggets',
#  'description': 'twitch.tv/teddywang86.',
#  'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/default.jpg',
#    'width': 120,
#    'height': 90},
#   'medium': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/mqdefault.jpg',
#    'width': 320,
#    'height': 180},
#   'high': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/hqdefault.jpg',
#    'width': 480,
#    'height': 360}},
#  'channelTitle': 'teddywang86',
#  'liveBroadcastContent': 'none',
#  'publishTime': '2024-01-11T14:36:20Z'}

# %%
dict_videos = {"id":[], "channelTitle":[], "publish":[], "description":[], "title_video":[]} # Se crea diccionario con valores de listas vacías

for i in search_response["items"]: # Iterar listas
    dict_videos["id"].append(i["id"]["videoId"]) 
    dict_videos["channelTitle"].append(i["snippet"]["channelTitle"])
    dict_videos["publish"].append(i["snippet"]["publishTime"])
    dict_videos["description"].append(i["snippet"]["description"])
    dict_videos["title_video"].append(i["snippet"]["title"])

df_video_y = pd.DataFrame(dict_videos)
df_video_y
# Out:
#              id             channelTitle               publish  \
# 0   1t6FNyW3JmE              teddywang86  2024-01-11T14:36:20Z
# 1   vy-5CeyOKkQ              teddywang86  2024-09-10T12:51:58Z
# 2   7i9gM8dJcBo              teddywang86  2024-01-31T14:31:14Z
# 3   KgYvmhCrm7c                      SLG  2023-11-27T20:00:12Z
# 4   UHII6fBlDbI              teddywang86  2024-01-12T12:25:23Z
# 5   kHWyJ-baLnE                     Zdak  2024-12-25T12:52:33Z
# 6   i-WypxLBGhY            Evelyn Hutani  2024-11-20T10:58:54Z
# 7   dPZ8uUvrgZQ           Trippy Kitchen  2023-01-21T16:48:41Z
# 8   hptchvNnsoI              teddywang86  2025-05-28T03:03:33Z
# 9   0xZQ0Sut8JY                BadgerBOI  2024-12-20T11:00:03Z
# 10  dvQWEI1uiBw          Diosdado Juarez  2025-01-29T21:36:09Z
# 11  UCJaFnquajo                  mosambi  2024-01-04T08:00:14Z
# 12  Hj_tvOn40zg              teddywang86  2024-09-16T07:43:06Z
# 13  Y58J4kbRNHk                    SnipZ  2025-05-24T16:00:37Z
# 14  fBhMqSXGRhI              teddywang86  2024-01-16T06:05:51Z
# 15  ZNHjgcprFSs              teddywang86  2025-05-20T05:21:47Z
# 16  vJefOB8kec8             Dhruv Rathee  2023-07-16T15:05:29Z
# 17  t0x6WNItdX4             Agnit Shorts  2023-04-12T04:30:22Z
# 18  Twpp0mJjDRQ    Mysterious Chronicles  2023-12-26T22:53:34Z
# 19  acGZaDV1o04       HumorMuyArtificial  2024-05-12T11:24:59Z
# 20  JJFXdtJr-oI              teddywang86  2025-06-07T11:26:54Z
# 21  sdffuJU0mEw              Timmy Blox®  2024-06-12T15:53:46Z
# 22  71jJ9ovMAqE                   Ashley  2025-03-01T22:58:43Z
# 23  4WwXqtBaXI4               MiniMoochi  2025-05-10T16:00:06Z
# 24  Ur5u27nLIhk           Watch With Sam  2025-02-13T12:47:08Z
# 25  sITD5peEOmM                   Vulrax  2024-10-15T14:10:01Z
# 26  qWqFkhDp1vo              teddywang86  2024-01-15T08:23:33Z
# 27  4op1bEkZQ7M              Mad Prateek  2025-03-06T11:30:04Z
# 28  OHTy96KPZHY              teddywang86  2024-09-24T14:58:03Z
# 29  hqoSXDiP4HY                NEUROVIBE  2025-01-25T14:31:58Z
# 30  cDSI29p6KsU           Ayush More 2.0  2024-01-12T04:23:51Z
# 31  ltbllHSs-JQ              teddywang86  2024-09-13T16:58:21Z
# 32  FdZ8LKiJBhQ             Nate Gentile  2023-03-07T21:24:03Z
# 33  JTxsNm9IdYU            Adrian Twarog  2022-12-12T10:52:13Z
# 34  j02OZRjf2d8  New Media Academy Life   2023-03-07T18:00:08Z
# 35  vx8mVmRQqms              teddywang86  2024-09-20T03:11:56Z
# 36  D3tFS26uxQ0              Futurepedia  2024-05-15T08:23:20Z
# 37  Z0qe9sLvVRY      Собиратель новостей  2025-04-30T15:45:06Z
# 38  eefptKQMezA                    ITBOX  2025-04-24T11:00:59Z
# 39  uuLrZjQ4tgI              Angry Prash  2024-12-19T13:33:11Z
# 40  AXn2XVLf7d0         The AI Advantage  2022-12-08T21:56:41Z
# 41  BjMMqm-v9CY                Mac Macha  2025-05-09T11:39:28Z
# 42  mNxB1g1-Otg            [ Unchained ]  2023-12-22T16:16:28Z
# 43  FtIEhrZD_5I                 Alakh GK  2023-06-21T16:22:23Z
# 44  iI8xcDKdTsg    Motivation QuoteShala  2024-01-25T15:24:05Z
# 45  Gaf_jCnA6mc            Charlie Chang  2023-04-04T18:09:53Z
# 46  iWhlrkfJrCQ              GothamChess  2023-02-13T16:17:00Z
# 47  I4i2TdvShnM              teddywang86  2024-10-17T15:31:27Z
# 48  5ROUtomUTsI               Strikker 2  2024-05-08T17:17:29Z
# 49  cqsToLyNUjw            Saddam Kassim  2024-08-10T05:53:53Z
#
#                                           description  \
# 0                              twitch.tv/teddywang86.
# 1
# 2                              twitch.tv/teddywang86.
# 3
# 4                              twitch.tv/teddywang86.
# 5   ChatGPT cooked bro, fr Funny Chat GPT conversa...
# 6
# 7
# 8
# 9   In this short meme we see how stupid AI (chat ...
# 10
# 11                                  I ask chat GPT...
# 12
# 13  Conversation with Chat GPT x Kurt Angle starin...
# 14                             twitch.tv/teddywang86.
# 15
# 16  Join my AI Course: https://academy.dhruvrathee...
# 17                       I DEFEATED CHAT GPT #shorts.
# 18  Immerse yourself in a groundbreaking fusion of...
# 19  Este canal se dedica a crear videos con imagen...
# 20
# 21  AI memes GPT 39  #sasagix #ai #chatgpt #midjou...
# 22
# 23  Join the ✨MOOCHIS MEMBERSHIP✨ to get access to...
# 24  Motivation , Inspiration or Information? Just ...
# 25  shorts guess the emoji games and hard choice g...
# 26                             twitch.tv/teddywang86.
# 27
# 28
# 29
# 30
# 31
# 32  REGISTRATE A LA GTC Y ASISTE A UNA SESIÓN PARA...
# 33  This ChatGPT Tutorial is a Crash Course on Cha...
# 34  رحلة داخل الذكاء الاصطناعي اللي عارف ومش عارف ...
# 35
# 36                  Open AI voice agents with GPT-4o.
# 37  ChatGPT спас девушку от рака — она попросила е...
# 38  realmadrid #milan #popefrancis #vatican #codin...
# 39  This cartoon comedy video is about what if cha...
# 40  Looking to get more out of ChatGPT? Get my FRE...
# 41
# 42  Code : unchained sur Fortnite ! Abonne-toi à m...
# 43                      ChatGPT #HowToUseChatGPT #AI.
# 44  AI Predicts Your Exam Result Conversation with...
# 45  Get up to 75% off your hosting (only $2.99/mo)...
# 46  Get My Chess Courses: https://www.chessly.com/...
# 47
# 48  ChatGPT VS Google Bard - x1 LEGENDÁRIO! #aiart...
# 49  Looking to earn money online using ChatGPT? He...
#
#                                           title_video
# 0                    ChatGPT, Show Me Chicken Nuggets
# 1                           ChatGPT, Show Me an Apple
# 2                            ChatGPT, Repeat After Me
# 3             I asked Chat GPT to make an angry puppy
# 4                     ChatGPT, Show Me Mac and Cheese
# 5                                ChatGPT is savage ☠️
# 6                          Chat GPT kalo jd manusia 🤡
# 7                 Chat GPT A.I. Ki help se banai dish
# 8                               ChatGPT, Show Me Rice
# 9                           Chat GPT isn&#39;t smart🤡
# 10                   CHAT GPT me dijo algo raro😰😱🤯😵‍💫
# 11                                 I ask chat GPT...🤔
# 12                   ChatGPT, Show Me a Chocolate Bar
# 13                             ChatGPT went too far 💀
# 14                          ChatGPT, Show Me American
# 15                   ChatGPT, Show Me Dubai Chocolate
# 16  The Truth about Artificial Intelligence and Ch...
# 17                     I DEFEATED ChatGPT !!! #shorts
# 18  Chat GPT AI Generated Image of God #mystery #a...
# 19  📱Teléfono de $1 vs $1,000,000,000 🤑💸 COMENTA C...
# 20                     ChatGPT, Show Me Instant Ramen
# 21  🥨AI memes GPT 39🤖#sasagix  #ai #chatgpt #midjo...
# 22                                       El chat GPT:
# 23    If CHATGPT was Human @davidmatthew_ #shortsfeed
# 24                 Narendra Modi Exposed Chat Gpt 😲🔥💯
# 25                        I ask Chat GPT... 😱 #shorts
# 26                           ChatGPT, Show Me Lasagna
# 27                     Chatgpt, Give me Sambar Vada😋🍩
# 28                 ChatGPT, Show Me Lays Potato Chips
# 29  Котик придумал, как сбежать домой в нейросети ...
# 30                  I ask Chat GPT #AyushMore #Shorts
# 31                        ChatGPT, Show Me a Dumpling
# 32  ¿Cómo funciona ChatGPT? La revolución de la In...
# 33  ChatGPT Tutorial - A Crash Course on Chat GPT ...
# 34                                  Chat GPT | الدحيح
# 35                      ChatGPT, Show Me a Watermelon
# 36                           GPT-4o talking to GPT-4o
# 37        Chat GPT Случайно Нашёл у Девушки ОНКОЛОГИЮ
# 38      POV COPY-PASTE HASIL CODINGAN DARI CHAT GPT 😂
# 39  If ChatGPT Was Indian Government Office? | Ang...
# 40       How To Use Chat GPT by Open AI For Beginners
# 41  Chat GPT vs Amma | Mac Macha | Family comedy |...
# 42  J&#39;ai demandé à Chat GPT de me faire un Chi...
# 43  CHAT GPT और Artificial Intelligence | कैसे GPT...
# 44  AI Predicts Your Exam Result 😱 Conversation wi...
# 45  ChatGPT Tutorial: How to Use Chat GPT For Begi...
# 46                                    ChatGPT cheated
# 47                            ChatGPT, Show Me Subway
# 48            ChatGPT VS Google Bard - x1 LEGENDÁRIO!
# 49  ChatGPT Earn Money | Earn with ChatGPT | ChatG...

# %%
search_response = youtube.search().list(
  q="Chat gpt",
  part="snippet",
  order="viewCount",
  type="video",
  maxResults=50
).execute()

id_video = []
channelTitle = []
publish_time = []
description = []
title_video = []

for search_result in search_response.get("items", []):
    id_video.append(search_result["id"]["videoId"])
    channelTitle.append(search_result["snippet"]["channelTitle"])
    publish_time.append(search_result["snippet"]["publishTime"])
    description.append(search_result["snippet"]["description"])
    title_video.append(search_result["snippet"]["title"])


duration = []
definition = []
closed_caption = []
license_content = []
madeforkids = []
view_count = []
like_count = []
favorite_count = []
comment_count = []
license = []

for id_video_search in id_video:
    video_info_response = youtube.videos().list(
      part = ["contentDetails", "statistics","status"],
      id = id_video_search
    ).execute()

    duration .append(video_info_response["items"][0]['contentDetails']["duration"])
    definition.append(video_info_response["items"][0]['contentDetails']["definition"])
    closed_caption.append(video_info_response["items"][0]['contentDetails']["caption"])
    license_content.append(video_info_response["items"][0]['contentDetails']["licensedContent"])
    madeforkids.append(video_info_response["items"][0]['status']["madeForKids"])
    license.append(video_info_response["items"][0]['status']["license"])
    view_count.append(video_info_response["items"][0]['statistics']["viewCount"])
    like_count.append(video_info_response["items"][0]['statistics']["likeCount"])
    favorite_count.append(video_info_response["items"][0]['statistics']["favoriteCount"])
    comment_count.append(video_info_response["items"][0]['statistics'].get("commentCount", None))
    

df_youtube = pd.DataFrame({"id_video": id_video,
                           "Channel": channelTitle,
                           "title" : title_video,
                           "description": description,
                           "publish_time": publish_time,
                           "duration":duration,
                           "definiton": definition,
                           "closed_caption":closed_caption,
                           "license_content": license_content,
                           "madeforkids":madeforkids,
                           "license": license,
                           "view_count": view_count,
                           "like_count":like_count,
                           "favorite_count" : favorite_count,
                           "comment_count": comment_count
                           })
df_youtube.head()
# Out:
#       id_video      Channel                                    title  \
# 0  1t6FNyW3JmE  teddywang86         ChatGPT, Show Me Chicken Nuggets
# 1  vy-5CeyOKkQ  teddywang86                ChatGPT, Show Me an Apple
# 2  7i9gM8dJcBo  teddywang86                 ChatGPT, Repeat After Me
# 3  KgYvmhCrm7c          SLG  I asked Chat GPT to make an angry puppy
# 4  UHII6fBlDbI  teddywang86          ChatGPT, Show Me Mac and Cheese
#
#               description          publish_time duration definiton  \
# 0  twitch.tv/teddywang86.  2024-01-11T14:36:20Z     PT1M        hd
# 1                          2024-09-10T12:51:58Z    PT59S        hd
# 2  twitch.tv/teddywang86.  2024-01-31T14:31:14Z    PT32S        hd
# 3                          2023-11-27T20:00:12Z     PT1M        hd
# 4  twitch.tv/teddywang86.  2024-01-12T12:25:23Z     PT1M        hd
#
#   closed_caption  license_content  madeforkids  license view_count like_count  \
# 0          false             True        False  youtube   82237994    2359286
# 1          false             True        False  youtube   49365877    1913607
# 2          false             True        False  youtube   43880456    1057504
# 3          false             True        False  youtube   34200543    1662998
# 4          false             True        False  youtube   33516894    1050539
#
#   favorite_count comment_count
# 0              0          5851
# 1              0          4930
# 2              0          2067
# 3              0          7619
# 4              0          1796

# %%
search_response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'PAu_TVIgaqvZBA4MWb9aiI_Rzew',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'ES',
#  'pageInfo': {'totalResults': 866448, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'A6Vsz2BbCAmTgmSNrF39CJVyvRg',
#    'id': {'kind': 'youtube#video', 'videoId': '1t6FNyW3JmE'},
#    'snippet': {'publishedAt': '2024-01-11T14:36:20Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Chicken Nuggets',
#     'description': 'twitch.tv/teddywang86.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-11T14:36:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '9ld7FtT0wwVeSByU-5nwphQ57Xs',
#    'id': {'kind': 'youtube#video', 'videoId': 'vy-5CeyOKkQ'},
#    'snippet': {'publishedAt': '2024-09-10T12:51:58Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me an Apple',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vy-5CeyOKkQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vy-5CeyOKkQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vy-5CeyOKkQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-10T12:51:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'kESG8Zh4hZzCtuo7rKZwsEgx0O4',
#    'id': {'kind': 'youtube#video', 'videoId': '7i9gM8dJcBo'},
#    'snippet': {'publishedAt': '2024-01-31T14:31:14Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Repeat After Me',
#     'description': 'twitch.tv/teddywang86.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7i9gM8dJcBo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7i9gM8dJcBo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7i9gM8dJcBo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-31T14:31:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nwCIyuOj1MM9doDIc7-a-Tc5H1U',
#    'id': {'kind': 'youtube#video', 'videoId': 'KgYvmhCrm7c'},
#    'snippet': {'publishedAt': '2023-11-27T20:00:12Z',
#     'channelId': 'UC9-57Ntc215xLogxRrvy57w',
#     'title': 'I asked Chat GPT to make an angry puppy',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KgYvmhCrm7c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/KgYvmhCrm7c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/KgYvmhCrm7c/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'SLG',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-27T20:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'U7E8e2RlIoCgjtCzC2fPOjfXp5A',
#    'id': {'kind': 'youtube#video', 'videoId': 'UHII6fBlDbI'},
#    'snippet': {'publishedAt': '2024-01-12T12:25:23Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Mac and Cheese',
#     'description': 'twitch.tv/teddywang86.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UHII6fBlDbI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UHII6fBlDbI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UHII6fBlDbI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-12T12:25:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'luTHS3j5SY11kTTWCVk5mORwrpU',
#    'id': {'kind': 'youtube#video', 'videoId': 'gj0Y_JFWaTA'},
#    'snippet': {'publishedAt': '2023-12-25T13:01:37Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me a Hamburger',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gj0Y_JFWaTA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gj0Y_JFWaTA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gj0Y_JFWaTA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-25T13:01:37Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zM-N4NxSpOis4zr8xyQQs2KCAdw',
#    'id': {'kind': 'youtube#video', 'videoId': 'kHWyJ-baLnE'},
#    'snippet': {'publishedAt': '2024-12-25T12:52:33Z',
#     'channelId': 'UC_485Ao_SxlCaBlOZORVsVQ',
#     'title': 'ChatGPT is savage ☠️',
#     'description': 'ChatGPT cooked bro, fr Funny Chat GPT conversation "Pick a number from 1 to 50" x Mortal Kombat skeleton smoking cigar ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kHWyJ-baLnE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kHWyJ-baLnE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kHWyJ-baLnE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Zdak',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-12-25T12:52:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zTEf58A64EXLU40PuqXmIFEHL04',
#    'id': {'kind': 'youtube#video', 'videoId': 'i-WypxLBGhY'},
#    'snippet': {'publishedAt': '2024-11-20T10:58:54Z',
#     'channelId': 'UCB-Vy4-UoNHzhgntloAhC8w',
#     'title': 'Chat GPT kalo jd manusia 🤡',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i-WypxLBGhY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/i-WypxLBGhY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/i-WypxLBGhY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Evelyn Hutani',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-20T10:58:54Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ltNeTSLPVeXDff1l0xbJ3pD-MBE',
#    'id': {'kind': 'youtube#video', 'videoId': 'dPZ8uUvrgZQ'},
#    'snippet': {'publishedAt': '2023-01-21T16:48:41Z',
#     'channelId': 'UCujkLB4kBWRn0YIGVczzEDg',
#     'title': 'Chat GPT A.I. Ki help se banai dish',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Trippy Kitchen',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-21T16:48:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'M5BCvyW89eFT6e0blgBjgMjhKZM',
#    'id': {'kind': 'youtube#video', 'videoId': 'TwPFDbuBLcc'},
#    'snippet': {'publishedAt': '2024-07-31T16:00:34Z',
#     'channelId': 'UCWajepQsMCmNBUHVIPirk8g',
#     'title': 'nobody: ChatGPT',
#     'description': 'comedy #funnyvideo #chatgpt #ai #robot.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TwPFDbuBLcc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TwPFDbuBLcc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TwPFDbuBLcc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Helen Christie',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-07-31T16:00:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PtC4PbeOJDInw_a9NkvL8tgRYaM',
#    'id': {'kind': 'youtube#video', 'videoId': 'kvTs_nbc8Eg'},
#    'snippet': {'publishedAt': '2023-02-12T09:15:01Z',
#     'channelId': 'UCUV5-V-QKR3tUTkKE1X_QMA',
#     'title': 'ChatGPT vs Stockfish',
#     'description': 'Learn Chess: https://www.youtube.com/gothamchess ➡️ Free Chess Courses: https://www.chessly.com ➡️ Probably Edited ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kvTs_nbc8Eg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kvTs_nbc8Eg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kvTs_nbc8Eg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Gotham Clips',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-12T09:15:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nqq0ef6xzV4XSP6XW21auKj1R1o',
#    'id': {'kind': 'youtube#video', 'videoId': 'hptchvNnsoI'},
#    'snippet': {'publishedAt': '2025-05-28T03:03:33Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Rice',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hptchvNnsoI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hptchvNnsoI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hptchvNnsoI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-28T03:03:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '20_i14n2R_CymL9kl4QU15RuZag',
#    'id': {'kind': 'youtube#video', 'videoId': '0xZQ0Sut8JY'},
#    'snippet': {'publishedAt': '2024-12-20T11:00:03Z',
#     'channelId': 'UCYA6b_yndwNvv6ZaE6g485g',
#     'title': 'Chat GPT isn&#39;t smart🤡',
#     'description': 'In this short meme we see how stupid AI (chat GPT) can be, when asked something. Peter griffin from family guy a dollar meme ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0xZQ0Sut8JY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0xZQ0Sut8JY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0xZQ0Sut8JY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BadgerBOI',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-12-20T11:00:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'uXrhjrR_cfKlh-iv298N6uk434A',
#    'id': {'kind': 'youtube#video', 'videoId': 'vx0_3BIwUwE'},
#    'snippet': {'publishedAt': '2023-12-14T20:45:02Z',
#     'channelId': 'UCJvBXBYPWE1aIlrM0r1Ilhw',
#     'title': 'TROLLING CHATGPT 4',
#     'description': "I decided to troll ChatGPT by pushing its buttons. Show me a picture of nothing, ChatGPT. It's that simple. In this video I use the AI ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vx0_3BIwUwE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vx0_3BIwUwE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vx0_3BIwUwE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Greenskull AI',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-14T20:45:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '1q1JGiGAf27atHT3UuXnt4auG9U',
#    'id': {'kind': 'youtube#video', 'videoId': 'JHqJ2Ju3U7k'},
#    'snippet': {'publishedAt': '2024-06-18T12:47:00Z',
#     'channelId': 'UCC-Zhd1UVyJUmjpaunmHvBQ',
#     'title': 'Did You Brush Your Teeth? (Ai Edition) 😬 #ai #chatgpt #aiart',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JHqJ2Ju3U7k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JHqJ2Ju3U7k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JHqJ2Ju3U7k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'ReallyNotAi',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-06-18T12:47:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'QEJrHRKa6ftwuJouU2aJy74PfYQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'dvQWEI1uiBw'},
#    'snippet': {'publishedAt': '2025-01-29T21:36:09Z',
#     'channelId': 'UC0gnpMXQFvO9YsRZ_2adXPA',
#     'title': 'CHAT GPT me dijo algo raro😰😱🤯😵\u200d💫',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dvQWEI1uiBw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dvQWEI1uiBw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dvQWEI1uiBw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Diosdado Juarez',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-01-29T21:36:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Qv28CZauSpYwk-iQIJ-aZZWMwGQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'Hj_tvOn40zg'},
#    'snippet': {'publishedAt': '2024-09-16T07:43:06Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me a Chocolate Bar',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Hj_tvOn40zg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Hj_tvOn40zg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Hj_tvOn40zg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-16T07:43:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'xennAulI9TJdNl6fthYOQ1enkRk',
#    'id': {'kind': 'youtube#video', 'videoId': 'Y58J4kbRNHk'},
#    'snippet': {'publishedAt': '2025-05-24T16:00:37Z',
#     'channelId': 'UCsEX3MVZL8wGZSA4kCaQuWw',
#     'title': 'ChatGPT went too far 💀',
#     'description': 'Conversation with Chat GPT x Kurt Angle staring meme ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Y58J4kbRNHk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Y58J4kbRNHk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Y58J4kbRNHk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'SnipZ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-24T16:00:37Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qXr68eMrMadkLRuxJ6wR6-p9Hq0',
#    'id': {'kind': 'youtube#video', 'videoId': 'rqI3xF9vDd0'},
#    'snippet': {'publishedAt': '2023-09-13T16:29:50Z',
#     'channelId': 'UCYeF244yNGuFefuFKqxIAXw',
#     'title': 'How to fool Chat GPT with non-linear thinking #chatgpt',
#     'description': 'Watch mathematician Kit Yates describe the problem with linear thinking and Chat GPT. Watch the full video here: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rqI3xF9vDd0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rqI3xF9vDd0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rqI3xF9vDd0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Royal Institution',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-13T16:29:50Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tPRQFe-4Jk_MjNO-TB2m4uaZO9M',
#    'id': {'kind': 'youtube#video', 'videoId': 'fBhMqSXGRhI'},
#    'snippet': {'publishedAt': '2024-01-16T06:05:51Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me American',
#     'description': 'twitch.tv/teddywang86.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fBhMqSXGRhI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fBhMqSXGRhI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fBhMqSXGRhI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-16T06:05:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'YNd235Dubskbnhv95qBh02tuEB4',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZNHjgcprFSs'},
#    'snippet': {'publishedAt': '2025-05-20T05:21:47Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Dubai Chocolate',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZNHjgcprFSs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZNHjgcprFSs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZNHjgcprFSs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-20T05:21:47Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4dgUFA5LQJK2gY1BylAjvjoxXvE',
#    'id': {'kind': 'youtube#video', 'videoId': 'vJefOB8kec8'},
#    'snippet': {'publishedAt': '2023-07-16T15:05:29Z',
#     'channelId': 'UC-CSyyi47VX1lD9zyeABW3w',
#     'title': 'The Truth about Artificial Intelligence and ChatGPT | Dhruv Rathee',
#     'description': 'Join my AI Course: https://academy.dhruvrathee.com/chatgpt Learn to harness the power of ChatGPT effectively and transform ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vJefOB8kec8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vJefOB8kec8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vJefOB8kec8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Dhruv Rathee',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-16T15:05:29Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'm3ye2d1WaTYO9rHf1SXhqcLJxZk',
#    'id': {'kind': 'youtube#video', 'videoId': 't0x6WNItdX4'},
#    'snippet': {'publishedAt': '2023-04-12T04:30:22Z',
#     'channelId': 'UCu6eDhSb-UJq7_vLgKe4vHw',
#     'title': 'I DEFEATED ChatGPT !!! #shorts',
#     'description': 'I DEFEATED CHAT GPT #shorts.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/t0x6WNItdX4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/t0x6WNItdX4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/t0x6WNItdX4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Agnit Shorts',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-04-12T04:30:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'p9_2kkmRLlFdV0G2r8pjv1A7090',
#    'id': {'kind': 'youtube#video', 'videoId': 'Twpp0mJjDRQ'},
#    'snippet': {'publishedAt': '2023-12-26T22:53:34Z',
#     'channelId': 'UCxkgpR98geayprAcMhUW5TQ',
#     'title': 'Chat GPT AI Generated Image of God #mystery #artificalintelligence #joeroganpodcast #shorts #ai #art',
#     'description': 'Immerse yourself in a groundbreaking fusion of artificial intelligence and divine inspiration as ChatGPT AI unveils an ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Twpp0mJjDRQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Twpp0mJjDRQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Twpp0mJjDRQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Mysterious Chronicles',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-26T22:53:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'oV6LQpepf6xMXmamLOeXkGRO5sU',
#    'id': {'kind': 'youtube#video', 'videoId': 'acGZaDV1o04'},
#    'snippet': {'publishedAt': '2024-05-12T11:24:59Z',
#     'channelId': 'UCUetYLN8ZnErkC0NmF0wfcA',
#     'title': '📱Teléfono de $1 vs $1,000,000,000 🤑💸 COMENTA CUAL PREFIERES 😁 #humor #comedia #chatgpt #ia',
#     'description': 'Este canal se dedica a crear videos con imagenes de inteligencia artificial! Imagenes IA, memes IA, chistes IA, humor IA y mucho ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/acGZaDV1o04/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/acGZaDV1o04/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/acGZaDV1o04/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'HumorMuyArtificial',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-12T11:24:59Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'aOEDXo6g2Hl0zTF_uHfvxe85L-8',
#    'id': {'kind': 'youtube#video', 'videoId': 'UNKUQAy-zZs'},
#    'snippet': {'publishedAt': '2024-09-02T18:43:06Z',
#     'channelId': 'UCP6quduw_2xMkaypYoKCTKw',
#     'title': '🤑 IA Memes GPT LOL 20 🤣 #chatgpt #ia #humor #gracioso #memes',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UNKUQAy-zZs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UNKUQAy-zZs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UNKUQAy-zZs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Legenda Isa',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-02T18:43:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'iK4FI4j-b5kyyXf69w8dbvYY208',
#    'id': {'kind': 'youtube#video', 'videoId': 'JJFXdtJr-oI'},
#    'snippet': {'publishedAt': '2025-06-07T11:26:54Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Instant Ramen',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JJFXdtJr-oI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JJFXdtJr-oI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JJFXdtJr-oI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-06-07T11:26:54Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zz8mh5AgLTwR1Al--G2ImWLasvY',
#    'id': {'kind': 'youtube#video', 'videoId': '6q2xr2hBncc'},
#    'snippet': {'publishedAt': '2025-02-10T15:15:28Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me an Orange',
#     'description': 'Twitch: https://www.twitch.tv/teddywang86 Discord Community: https://discord.com/invite/Squja3KAgs TikTok: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6q2xr2hBncc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6q2xr2hBncc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6q2xr2hBncc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-10T15:15:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FS1e7JmvEVAEtIxfYkFwRpEkbco',
#    'id': {'kind': 'youtube#video', 'videoId': 'sdffuJU0mEw'},
#    'snippet': {'publishedAt': '2024-06-12T15:53:46Z',
#     'channelId': 'UCe3yKFEAXQ4IYej6Ea8bVcg',
#     'title': '🥨AI memes GPT 39🤖#sasagix  #ai #chatgpt #midjourney #humor #memes #aiartis #roblox',
#     'description': 'AI memes GPT 39  #sasagix #ai #chatgpt #midjourney #humor #memes #aiartis #roblox Memes creados con Inteligencia ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sdffuJU0mEw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sdffuJU0mEw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sdffuJU0mEw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Timmy Blox®',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-06-12T15:53:46Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'EM-kgAdlAXTRf4cBg7rjDjttnBg',
#    'id': {'kind': 'youtube#video', 'videoId': '71jJ9ovMAqE'},
#    'snippet': {'publishedAt': '2025-03-01T22:58:43Z',
#     'channelId': 'UCjXUF1XzXG0YQVv9Gwkuguw',
#     'title': 'El chat GPT:',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/71jJ9ovMAqE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/71jJ9ovMAqE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/71jJ9ovMAqE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Ashley',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-03-01T22:58:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3-t4wcNhnqJo5htdI4nBHQzkQ0k',
#    'id': {'kind': 'youtube#video', 'videoId': '4WwXqtBaXI4'},
#    'snippet': {'publishedAt': '2025-05-10T16:00:06Z',
#     'channelId': 'UCAQOf_uPOJ6rXO_k9RwfK3A',
#     'title': 'If CHATGPT was Human @davidmatthew_ #shortsfeed',
#     'description': 'Join the ✨MOOCHIS MEMBERSHIP✨ to get access to perks: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4WwXqtBaXI4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4WwXqtBaXI4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4WwXqtBaXI4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'MiniMoochi',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-10T16:00:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'dah_SItlUfAPx09vsc34rv9pvr4',
#    'id': {'kind': 'youtube#video', 'videoId': 'pZ59lKxt9w0'},
#    'snippet': {'publishedAt': '2024-09-21T02:51:22Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Eggs',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pZ59lKxt9w0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pZ59lKxt9w0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pZ59lKxt9w0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-21T02:51:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'NWExcbkOofWgzmz4wUAmO8YD3qk',
#    'id': {'kind': 'youtube#video', 'videoId': 'Ur5u27nLIhk'},
#    'snippet': {'publishedAt': '2025-02-13T12:47:08Z',
#     'channelId': 'UCzv4Z4UaBoJFZNyeerjCt6w',
#     'title': 'Narendra Modi Exposed Chat Gpt 😲🔥💯',
#     'description': "Motivation , Inspiration or Information? Just follow @Watchwithsam09. This content doesn't belong to us, it is edited and shared ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ur5u27nLIhk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ur5u27nLIhk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ur5u27nLIhk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Watch With Sam',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-13T12:47:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DV9mguAUoaI4kzKIOWXqIT42S68',
#    'id': {'kind': 'youtube#video', 'videoId': 'sITD5peEOmM'},
#    'snippet': {'publishedAt': '2024-10-15T14:10:01Z',
#     'channelId': 'UC0D24go3N0o1ItucFFoIShA',
#     'title': 'I ask Chat GPT... 😱 #shorts',
#     'description': 'shorts guess the emoji games and hard choice game and funny videos reaction mythpat and mythreacts crazy amazing guess the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sITD5peEOmM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sITD5peEOmM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sITD5peEOmM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Vulrax',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-10-15T14:10:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'x5FM3an38n8EPbYvY56o2TqgLrs',
#    'id': {'kind': 'youtube#video', 'videoId': 'qWqFkhDp1vo'},
#    'snippet': {'publishedAt': '2024-01-15T08:23:33Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Lasagna',
#     'description': 'twitch.tv/teddywang86.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qWqFkhDp1vo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qWqFkhDp1vo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qWqFkhDp1vo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-15T08:23:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'rHhDbkEDOpPAiBbo2ulePpR8AR8',
#    'id': {'kind': 'youtube#video', 'videoId': '4op1bEkZQ7M'},
#    'snippet': {'publishedAt': '2025-03-06T11:30:04Z',
#     'channelId': 'UC2MtuHEvnlp5I9GhTuC0R1A',
#     'title': 'Chatgpt, Give me Sambar Vada😋🍩',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4op1bEkZQ7M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4op1bEkZQ7M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4op1bEkZQ7M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Mad Prateek',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-03-06T11:30:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5FhQQZxqP6puZsogdnfb-rjmXw4',
#    'id': {'kind': 'youtube#video', 'videoId': 'OHTy96KPZHY'},
#    'snippet': {'publishedAt': '2024-09-24T14:58:03Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Lays Potato Chips',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OHTy96KPZHY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OHTy96KPZHY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OHTy96KPZHY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-24T14:58:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4ZO_6jQHULLDWWrPH_dhVy3Cz28',
#    'id': {'kind': 'youtube#video', 'videoId': 'hqoSXDiP4HY'},
#    'snippet': {'publishedAt': '2025-01-25T14:31:58Z',
#     'channelId': 'UCMiEp9Ni-qbmxpPaGhbNPmA',
#     'title': 'Котик придумал, как сбежать домой в нейросети #dalle3 #chatgpt #кот #котики #юмор #aiart #ии #жиза',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hqoSXDiP4HY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hqoSXDiP4HY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hqoSXDiP4HY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'NEUROVIBE',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-01-25T14:31:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '9Is7yfR4vgNG9VpVO5UQH81FS14',
#    'id': {'kind': 'youtube#video', 'videoId': 'ltbllHSs-JQ'},
#    'snippet': {'publishedAt': '2024-09-13T16:58:21Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me a Dumpling',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ltbllHSs-JQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ltbllHSs-JQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ltbllHSs-JQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-13T16:58:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZlriufJZOndDXQgHjVvchqPd-Fc',
#    'id': {'kind': 'youtube#video', 'videoId': 'F16b1s5BkoQ'},
#    'snippet': {'publishedAt': '2023-03-28T16:00:20Z',
#     'channelId': 'UCCU2Tvanl8gLaJ7pYDuIYkg',
#     'title': 'Quand Timéo découvre Chat GPT…',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/F16b1s5BkoQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/F16b1s5BkoQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/F16b1s5BkoQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BATZAIR',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-28T16:00:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'SFiC7u82aItcaYHyyx_ymHO_zik',
#    'id': {'kind': 'youtube#video', 'videoId': 'FdZ8LKiJBhQ'},
#    'snippet': {'publishedAt': '2023-03-07T21:24:03Z',
#     'channelId': 'UC36xmz34q02JYaZYKrMwXng',
#     'title': '¿Cómo funciona ChatGPT? La revolución de la Inteligencia Artificial',
#     'description': 'REGISTRATE A LA GTC Y ASISTE A UNA SESIÓN PARA GANAR UNA GPU!',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FdZ8LKiJBhQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FdZ8LKiJBhQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FdZ8LKiJBhQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nate Gentile',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-07T21:24:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'MhD9nFMhUXgU7GRLyVsDM3OodKU',
#    'id': {'kind': 'youtube#video', 'videoId': 'JTxsNm9IdYU'},
#    'snippet': {'publishedAt': '2022-12-12T10:52:13Z',
#     'channelId': 'UCvM5YYWwfLwpcQgbRr68JLQ',
#     'title': 'ChatGPT Tutorial - A Crash Course on Chat GPT for Beginners',
#     'description': 'This ChatGPT Tutorial is a Crash Course on Chat GPT for Beginners. With the increase in popularity, ChatGPT is still unknown to ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JTxsNm9IdYU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JTxsNm9IdYU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JTxsNm9IdYU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Adrian Twarog',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-12T10:52:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wC_zxCwnS4j3BHpIxODGBuUwHCQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'j02OZRjf2d8'},
#    'snippet': {'publishedAt': '2023-03-07T18:00:08Z',
#     'channelId': 'UCtJmfVv0a52Bu7BnJJtZXKw',
#     'title': 'Chat GPT | الدحيح',
#     'description': 'رحلة داخل الذكاء الاصطناعي اللي عارف ومش عارف كل حاجة. شاهدوا حلقات الدحيح أولاً على منصات ستارز بلاي @STARZPLAYOfficial ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/j02OZRjf2d8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/j02OZRjf2d8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/j02OZRjf2d8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'New Media Academy Life ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-07T18:00:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mbl9bMyyOvtZ0Ed013Q1q5gYwGc',
#    'id': {'kind': 'youtube#video', 'videoId': 'vx8mVmRQqms'},
#    'snippet': {'publishedAt': '2024-09-20T03:11:56Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me a Watermelon',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vx8mVmRQqms/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vx8mVmRQqms/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vx8mVmRQqms/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-20T03:11:56Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fMPFGdn4g_1eFlTcgT_B-t1IUME',
#    'id': {'kind': 'youtube#video', 'videoId': '5MmxPFDLaEs'},
#    'snippet': {'publishedAt': '2024-08-08T12:42:19Z',
#     'channelId': 'UC7kIy8fZavEni8Gzl8NLjOQ',
#     'title': 'ChatGPT is a Liar',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5MmxPFDLaEs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5MmxPFDLaEs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5MmxPFDLaEs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': "Alex O'Connor",
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-08-08T12:42:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'RQVT547QyGbRRBIbBaTcWW039Nw',
#    'id': {'kind': 'youtube#video', 'videoId': 'D3tFS26uxQ0'},
#    'snippet': {'publishedAt': '2024-05-15T08:23:20Z',
#     'channelId': 'UC_RovKmk0OCbuZjA8f08opw',
#     'title': 'GPT-4o talking to GPT-4o',
#     'description': 'Open AI voice agents with GPT-4o.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/D3tFS26uxQ0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/D3tFS26uxQ0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/D3tFS26uxQ0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Futurepedia',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-15T08:23:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'KCFAPxD7WTXmU0cRHAy-1qlPwvM',
#    'id': {'kind': 'youtube#video', 'videoId': 'eefptKQMezA'},
#    'snippet': {'publishedAt': '2025-04-24T11:00:59Z',
#     'channelId': 'UCJosC3Lzjqhhr9n3PycMlFA',
#     'title': 'POV COPY-PASTE HASIL CODINGAN DARI CHAT GPT 😂',
#     'description': 'realmadrid #milan #popefrancis #vatican #coding #ai #elonmusk #donaldtrump #bitcoin #trading #indonesia #beritaviral #Bitcoin ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eefptKQMezA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eefptKQMezA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eefptKQMezA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'ITBOX',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-04-24T11:00:59Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Q6vwG_Londm82N0ZJAfoFxiwBYY',
#    'id': {'kind': 'youtube#video', 'videoId': 'uuLrZjQ4tgI'},
#    'snippet': {'publishedAt': '2024-12-19T13:33:11Z',
#     'channelId': 'UCz-iDa_Z-GWaZ_YweEus6iw',
#     'title': 'If ChatGPT Was Indian Government Office? | Angry Prash',
#     'description': 'This cartoon comedy video is about what if chatgpt was an Indian government office. Join Me On- Facebook▻- ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uuLrZjQ4tgI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uuLrZjQ4tgI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uuLrZjQ4tgI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Angry Prash',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-12-19T13:33:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ClnXSIsBk-69BZGbsnkvKNg54NA',
#    'id': {'kind': 'youtube#video', 'videoId': 'AXn2XVLf7d0'},
#    'snippet': {'publishedAt': '2022-12-08T21:56:41Z',
#     'channelId': 'UCHhYXsLBEVVnbvsq57n1MTQ',
#     'title': 'How To Use Chat GPT by Open AI For Beginners',
#     'description': "Looking to get more out of ChatGPT? Get my FREE presets: https://bit.ly/aianewsletter In this tutorial, I'll be showing you how to ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AXn2XVLf7d0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AXn2XVLf7d0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AXn2XVLf7d0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The AI Advantage',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-08T21:56:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'QEORPW7H0a1ReEszQMiFDWhGf3g',
#    'id': {'kind': 'youtube#video', 'videoId': 'BjMMqm-v9CY'},
#    'snippet': {'publishedAt': '2025-05-09T11:39:28Z',
#     'channelId': 'UCmC-wktipngCaU9nryMdbpQ',
#     'title': 'Chat GPT vs Amma | Mac Macha | Family comedy | #Shorts',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BjMMqm-v9CY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BjMMqm-v9CY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BjMMqm-v9CY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Mac Macha',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-09T11:39:28Z'}}]}

# %%
df_youtube.to_csv("data/df_youtube_chagpt.csv")

# %% [markdown]
# ## Google Gemini

# %%
api_key = "pon tu api key"

# %%
# !pip install google-genai
# Out:
# Collecting google-genai
#   Downloading google_genai-1.20.0-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (4.8.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (2.40.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (2.10.6)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (2.32.3)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (15.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)
# Downloading google_genai-1.20.0-py3-none-any.whl (203 kB)
# Installing collected packages: google-genai
# Successfully installed google-genai-1.20.0

# %%
from google import genai
from google.genai import types

# %%
from google import genai

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=["How does AI work?"]
)
print(response.text)
# Out:
# Okay, let's break down how AI works. It's a broad field, so I'll give you a general overview, then touch on some key concepts and techniques.
#
# **The Big Picture: Mimicking Intelligence**
#
# At its core, Artificial Intelligence (AI) aims to create machines or systems that can perform tasks that typically require human intelligence. These tasks can include:
#
# *   **Learning:** Acquiring information and rules for using the information.
# *   **Reasoning:** Using rules to reach conclusions.
# *   **Problem-solving:** Figuring out how to overcome difficulties.
# *   **Perception:** Understanding the world through senses (e.g., sight, sound).
# *   **Language understanding:** Comprehending and generating human language.
#
# **Two Main Approaches (Historically):**
#
# 1.  **Symbolic AI (Rule-Based AI):**
#     *   **How it works:** This approach focuses on representing knowledge as symbols and using logical rules to manipulate those symbols.  Think of it like programming a computer with a very detailed set of "if-then" statements.
#     *   **Example:** A medical diagnosis system might have rules like "IF patient has fever AND cough AND headache THEN suspect influenza."
#     *   **Pros:**  Explainable (you can see the rules), good for well-defined problems.
#     *   **Cons:**  Brittle (struggles with unexpected situations), difficult to scale to complex, real-world problems, requires explicit programming of all rules.
#
# 2.  **Connectionist AI (Neural Networks):**
#     *   **How it works:** Inspired by the structure of the human brain, this approach uses artificial neural networks. These networks consist of interconnected nodes (neurons) that process and transmit information.  The network learns by adjusting the strengths of the connections between neurons based on data.
#     *   **Example:** Image recognition. A neural network is trained on thousands of images of cats and dogs.  Through this training, it learns to identify patterns that distinguish cats from dogs.
#     *   **Pros:**  Can learn complex patterns from data, robust to noisy data, can generalize to new situations.
#     *   **Cons:**  "Black box" (difficult to understand *why* it made a certain decision), requires large amounts of data, computationally expensive.
#
# **Modern AI: A Blend and Evolution**
#
# Today's AI is often a combination of these approaches, with a strong emphasis on connectionist methods, particularly deep learning.  Here's a breakdown of key concepts:
#
# *   **Machine Learning (ML):** A subset of AI that focuses on enabling systems to learn from data without being explicitly programmed.  Instead of writing rules, you feed the system data, and it figures out the patterns.
#
#     *   **Types of Machine Learning:**
#         *   **Supervised Learning:**  The system is trained on labeled data (e.g., images of cats and dogs where each image is labeled as "cat" or "dog").  The goal is to learn a mapping from inputs to outputs.
#         *   **Unsupervised Learning:** The system is trained on unlabeled data.  The goal is to discover hidden patterns or structures in the data (e.g., clustering customers into different groups based on their purchasing behavior).
#         *   **Reinforcement Learning:** The system learns by interacting with an environment and receiving rewards or penalties for its actions.  Think of training a robot to walk by rewarding it for taking steps in the right direction.
#
# *   **Deep Learning (DL):** A subset of machine learning that uses artificial neural networks with many layers (hence "deep").  These deep networks can learn very complex patterns and representations from data.
#
#     *   **How it works:** Deep learning models take data as input, process it through multiple layers of interconnected nodes (neurons), and produce an output. Each layer learns to extract increasingly complex features from the data.
#     *   **Examples:** Image recognition, natural language processing, speech recognition.
#     *   **Key Architectures:** Convolutional Neural Networks (CNNs) for images, Recurrent Neural Networks (RNNs) for sequences (text, time series), Transformers (a newer architecture that is very powerful for NLP and other tasks).
#
# *   **Natural Language Processing (NLP):** A field of AI that focuses on enabling computers to understand, interpret, and generate human language.
#
#     *   **Tasks:**
#         *   **Text Classification:** Categorizing text (e.g., sentiment analysis: determining if a review is positive or negative).
#         *   **Machine Translation:** Translating text from one language to another.
#         *   **Question Answering:** Answering questions posed in natural language.
#         *   **Text Generation:** Generating text (e.g., writing articles, creating summaries).
#
# *   **Computer Vision:** A field of AI that focuses on enabling computers to "see" and interpret images and videos.
#
#     *   **Tasks:**
#         *   **Image Recognition:** Identifying objects in an image.
#         *   **Object Detection:** Locating objects in an image and drawing bounding boxes around them.
#         *   **Image Segmentation:** Dividing an image into regions based on different objects or features.
#
# **The AI Development Process (Simplified):**
#
# 1.  **Define the Problem:** What task do you want the AI to perform?
# 2.  **Gather Data:** Collect a large dataset relevant to the problem. The quality and quantity of data are crucial.
# 3.  **Choose a Model:** Select an appropriate AI model (e.g., a deep learning model, a decision tree, etc.).
# 4.  **Train the Model:** Feed the data into the model and allow it to learn the underlying patterns.
# 5.  **Evaluate the Model:** Test the model on a separate dataset to see how well it generalizes to new data.
# 6.  **Tune the Model:** Adjust the model's parameters to improve its performance. This often involves a lot of experimentation.
# 7.  **Deploy the Model:** Integrate the model into a real-world application.
# 8.  **Monitor and Retrain:** Continuously monitor the model's performance and retrain it with new data to keep it up-to-date.
#
# **Key Technologies and Tools:**
#
# *   **Programming Languages:** Python is the most popular language for AI development, followed by R, Java, and others.
# *   **AI Frameworks:** TensorFlow, PyTorch, Keras, scikit-learn are popular libraries that provide tools and functions for building and training AI models.
# *   **Cloud Computing:** Platforms like AWS, Google Cloud, and Azure provide the computational resources needed to train and deploy large AI models.
# *   **GPUs (Graphics Processing Units):** Specialized hardware that is very efficient at performing the matrix operations needed for deep learning.
#
# **Important Considerations:**
#
# *   **Ethics:** AI raises important ethical questions about bias, fairness, privacy, and accountability.
# *   **Data Bias:** AI models can perpetuate and amplify biases present in the data they are trained on.
# *   **Explainability:**  Understanding why an AI model made a particular decision is often difficult, but it's important for building trust and accountability.
# *   **Security:** AI systems can be vulnerable to attacks.
#
# **In summary:**
#
# AI is a complex and rapidly evolving field.  It involves creating systems that can perform tasks that typically require human intelligence. Modern AI relies heavily on machine learning, particularly deep learning, which uses artificial neural networks to learn from data. The development process involves defining the problem, gathering data, choosing a model, training the model, evaluating it, and deploying it.  It's also crucial to consider the ethical implications of AI and address potential biases and security vulnerabilities.
