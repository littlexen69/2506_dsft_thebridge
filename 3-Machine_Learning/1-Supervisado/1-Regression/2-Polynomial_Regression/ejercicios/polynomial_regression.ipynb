# %% [markdown]
# ### Objective:
#
# Develop a model to predict cost vs. number of units sold using polynomial regression
# - Independence variable X: number of units produced
# - Dependence variable Y: cost of good sold

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Data Understanding

# %%
# Out:
#    Number of Units  Manufacturing Cost
# 0         1.000000           95.066056
# 1         1.185994           96.531750
# 2         1.191499           73.661311
# 3         1.204771           95.566843
# 4         1.298773           98.777013

# %%
# Out:
#      Number of Units  Manufacturing Cost
# 995         8.099710           23.855067
# 996         8.739752           27.536542
# 997         8.780888           25.973787
# 998         8.897700           25.138311
# 999        10.000000           21.547777

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Number of Units     1000 non-null   float64
#  1   Manufacturing Cost  1000 non-null   float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %%
# Out:
#                      count       mean        std   min        25%        50%  \
# Number of Units     1000.0   4.472799   1.336241   1.0   3.594214   4.435958
# Manufacturing Cost  1000.0  40.052999  10.595322  20.0  32.912036  38.345781
#
#                           75%    max
# Number of Units      5.324780   10.0
# Manufacturing Cost  44.531822  100.0

# %%
# Out:
# (1000, 2)
# Index(['Number of Units', 'Manufacturing Cost'], dtype='object')

# %%
# Out:
# Number of Units       0
# Manufacturing Cost    0
# dtype: int64

# %%
# Out:
# np.int64(0)

# %% [markdown]
# ### Visualize Dataset

# %% [markdown]
# ### Create Train and Test Set

# %%
# Out:
#      Number of Units
# 29          1.865228
# 535         4.548429
# 695         5.112873
# 557         4.616828
# 836         5.665156
# ..               ...
# 106         2.834925
# 270         3.680402
# 860         5.855097
# 435         4.242124
# 102         2.794083
#
# [800 rows x 1 columns]

# %%
# Out:
# 29     55.036139
# 535    43.816361
# 695    41.611214
# 557    48.034208
# 836    33.554747
#          ...
# 106    48.723598
# 270    43.563355
# 860    37.939400
# 435    44.845931
# 102    57.488360
# Name: Manufacturing Cost, Length: 800, dtype: float64

# %%
# Out:
# (800, 1)
# (800,)
# (200, 1)
# (200,)

# %% [markdown]
# ### Train the Models

# %% [markdown]
# #### Linear Assumption

# %%
# Out:
# LinearRegression()

# %%
# Out:
# Linear Model coeff (m): [-6.21850698]
# Linear Model coeff (b): 67.89012908512075

# %%
# Out:
# LinearRegression(fit_intercept=False)

# %%
# Out:
# Linear Model coeff (m): [7.750607]
# Linear Model coeff (b): 0.0

# %% [markdown]
# #### Polynomial Assumption

# %%
# Out:
# array([[ 1.        ,  1.86522775,  3.47907457],
#        [ 1.        ,  4.54842911, 20.68820735],
#        [ 1.        ,  5.11287348, 26.14147523],
#        ...,
#        [ 1.        ,  5.85509721, 34.2821633 ],
#        [ 1.        ,  4.24212411, 17.99561697],
#        [ 1.        ,  2.79408325,  7.80690121]], shape=(800, 3))

# %%
# Out:
# LinearRegression()

# %%
# Out:
# Model Coeff: [  0.         -17.81636965   1.27181952]

# %%
# Out:
# array([[  1.        ,   1.86522775,   3.47907457,   6.48926643],
#        [  1.        ,   4.54842911,  20.68820735,  94.09884451],
#        [  1.        ,   5.11287348,  26.14147523, 133.65805547],
#        ...,
#        [  1.        ,   5.85509721,  34.2821633 , 200.72539861],
#        [  1.        ,   4.24212411,  17.99561697,  76.33964065],
#        [  1.        ,   2.79408325,   7.80690121,  21.81313192]],
#       shape=(800, 4))

# %%
# Out:
# LinearRegression()

# %%
# Out:
# Model Coeff: [  0.         -34.51814321   5.05171512  -0.26070502]

# %%
# Out:
# array([[1.00000000e+00, 1.86522775e+00, 3.47907457e+00, 6.48926643e+00,
#         1.21039598e+01],
#        [1.00000000e+00, 4.54842911e+00, 2.06882074e+01, 9.40988445e+01,
#         4.28001923e+02],
#        [1.00000000e+00, 5.11287348e+00, 2.61414752e+01, 1.33658055e+02,
#         6.83376727e+02],
#        ...,
#        [1.00000000e+00, 5.85509721e+00, 3.42821633e+01, 2.00725399e+02,
#         1.17526672e+03],
#        [1.00000000e+00, 4.24212411e+00, 1.79956170e+01, 7.63396407e+01,
#         3.23842230e+02],
#        [1.00000000e+00, 2.79408325e+00, 7.80690121e+00, 2.18131319e+01,
#         6.09477066e+01]], shape=(800, 5))

# %%
# Out:
# LinearRegression()

# %%
# Out:
# Model Coeff: [ 0.00000000e+00 -5.48053513e+01  1.21644641e+01 -1.26644861e+00
#   4.90848244e-02]

# %%
# Out:
# array([[1.00000000e+00, 1.86522775e+00, 3.47907457e+00, 6.48926643e+00,
#         1.21039598e+01, 2.25766418e+01],
#        [1.00000000e+00, 4.54842911e+00, 2.06882074e+01, 9.40988445e+01,
#         4.28001923e+02, 1.94673641e+03],
#        [1.00000000e+00, 5.11287348e+00, 2.61414752e+01, 1.33658055e+02,
#         6.83376727e+02, 3.49401875e+03],
#        ...,
#        [1.00000000e+00, 5.85509721e+00, 3.42821633e+01, 2.00725399e+02,
#         1.17526672e+03, 6.88130089e+03],
#        [1.00000000e+00, 4.24212411e+00, 1.79956170e+01, 7.63396407e+01,
#         3.23842230e+02, 1.37377893e+03],
#        [1.00000000e+00, 2.79408325e+00, 7.80690121e+00, 2.18131319e+01,
#         6.09477066e+01, 1.70292966e+02]], shape=(800, 6))

# %%
# Out:
# LinearRegression()

# %%
# Out:
# Model Coeff: [ 0.00000000e+00 -9.54138252e+01  3.19305847e+01 -5.63692225e+00
#   4.94554373e-01 -1.69105527e-02]

# %%
# Out:
# array([[1.00000000e+00, 1.86522775e+00, 3.47907457e+00, ...,
#         1.46505844e+02, 2.73266766e+02, 5.09704755e+02],
#        [1.00000000e+00, 4.54842911e+00, 2.06882074e+01, ...,
#         1.83185646e+05, 8.33206926e+05, 3.78978264e+06],
#        [1.00000000e+00, 5.11287348e+00, 2.61414752e+01, ...,
#         4.67003751e+05, 2.38773110e+06, 1.22081670e+07],
#        ...,
#        [1.00000000e+00, 5.85509721e+00, 3.42821633e+01, ...,
#         1.38125186e+06, 8.08736394e+06, 4.73523020e+07],
#        [1.00000000e+00, 4.24212411e+00, 1.79956170e+01, ...,
#         1.04873790e+05, 4.44887634e+05, 1.88726856e+06],
#        [1.00000000e+00, 2.79408325e+00, 7.80690121e+00, ...,
#         3.71462293e+03, 1.03789657e+04, 2.89996943e+04]], shape=(800, 11))

# %%
# Out:
# LinearRegression()

# %%
# Out:
# Model Coeff: [ 0.00000000e+00  1.10236664e+03 -1.74008207e+03  1.39096257e+03
#  -6.61711875e+02  2.00205730e+02 -3.95124534e+01  5.06585938e+00
#  -4.06352797e-01  1.85063125e-02 -3.64842791e-04]

# %%
def plot_polynomial(X_train, y_train, y_pred):
    if isinstance(X_train, (pd.DataFrame, pd.Series)):
        X_train_np = X_train.to_numpy().flatten()
    else:
        X_train_np = X_train.flatten()
    
    sorted_indices = np.argsort(X_train_np)
    sorted_X_train = X_train_np[sorted_indices]
    sorted_y_pred = y_pred[sorted_indices]
    
    plt.figure(figsize=(8, 6))
    plt.scatter(X_train_np, y_train, color='gray')
    plt.plot(sorted_X_train, sorted_y_pred, color='blue')
    plt.show()

# %%
plot_polynomial(X_train, y_train, y_pred_poly2)

# %%
plot_polynomial(X_train, y_train, y_pred_poly3)

# %%
plot_polynomial(X_train, y_train, y_pred_poly4)

# %%
plot_polynomial(X_train, y_train, y_pred_poly5)

# %%
plot_polynomial(X_train, y_train, y_pred_poly10)

# %% [markdown]
# ### Apply Models in Test Set

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_test, y_test, color='gray')
plt.plot(X_test, y_pred_test_lr, color='blue')

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_test, y_test, color='gray')
plt.plot(X_test, y_pred_test_lr2, color='blue')

# %%
plot_polynomial(X_test, y_test, y_pred_test_poly3)

# %%
plot_polynomial(X_test, y_test, y_pred_test_poly4)

# %%
plot_polynomial(X_test, y_test, y_pred_test_poly5)

# %%
plot_polynomial(X_test, y_test, y_pred_test_poly10)

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# #### Training Set Evaluation

# %%
def evaluate_model(y_true, y_pred, X_train, model_name):
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    n = len(y_true)
    p = X_train.shape[1]
    adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))
    
    metrics_df = pd.DataFrame({
        'R-squared': [r2],
        'Mean Absolute Error': [mae],
        'Mean Squared Error': [mse],
        'Root Mean Squared Error': [rmse],
        'Mean Absolute Percentage Error': [mape],
        'Adjusted R-squared': [adjusted_r2]
    }, index=[model_name])
    
    formatted_metrics_df = metrics_df.style.format("{:.6f}").highlight_max(axis=0)
    return formatted_metrics_df

# %%
display(evaluate_model(y_train, y_pred_lr, X_train, 'Linear Regression'))
display(evaluate_model(y_train, y_pred_lr2, X_train, 'Linear Regression (no intercept)'))
display(evaluate_model(y_train, y_pred_poly2, X_train, 'Polynomial Regression (2-Degree)'))
display(evaluate_model(y_train, y_pred_poly3, X_train, 'Polynomial Regression (3-Degree)'))
display(evaluate_model(y_train, y_pred_poly4, X_train, 'Polynomial Regression (4-Degree)'))
display(evaluate_model(y_train, y_pred_poly5, X_train, 'Polynomial Regression (5-Degree)'))
display(evaluate_model(y_train, y_pred_poly10, X_train, 'Polynomial Regression (10-Degree)'))
# Out:
# <style type="text/css">
# #T_4f62d_row0_col0, #T_4f62d_row0_col1, #T_4f62d_row0_col2, #T_4f62d_row0_col3, #T_4f62d_row0_col4, #T_4f62d_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_4f62d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f62d_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_4f62d_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_4f62d_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_4f62d_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_4f62d_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_4f62d_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f62d_level0_row0" class="row_heading level0 row0" >Linear Regression</th>
#       <td id="T_4f62d_row0_col0" class="data row0 col0" >0.579692</td>
#       <td id="T_4f62d_row0_col1" class="data row0 col1" >5.053413</td>
#       <td id="T_4f62d_row0_col2" class="data row0 col2" >50.299188</td>
#       <td id="T_4f62d_row0_col3" class="data row0 col3" >7.092192</td>
#       <td id="T_4f62d_row0_col4" class="data row0 col4" >0.129081</td>
#       <td id="T_4f62d_row0_col5" class="data row0 col5" >0.579166</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7c084_row0_col0, #T_7c084_row0_col1, #T_7c084_row0_col2, #T_7c084_row0_col3, #T_7c084_row0_col4, #T_7c084_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_7c084">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c084_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_7c084_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_7c084_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_7c084_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_7c084_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_7c084_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c084_level0_row0" class="row_heading level0 row0" >Linear Regression (no intercept)</th>
#       <td id="T_7c084_row0_col0" class="data row0 col0" >-2.609669</td>
#       <td id="T_7c084_row0_col1" class="data row0 col1" >15.400603</td>
#       <td id="T_7c084_row0_col2" class="data row0 col2" >431.977345</td>
#       <td id="T_7c084_row0_col3" class="data row0 col3" >20.784065</td>
#       <td id="T_7c084_row0_col4" class="data row0 col4" >0.368057</td>
#       <td id="T_7c084_row0_col5" class="data row0 col5" >-2.614193</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e67a1_row0_col0, #T_e67a1_row0_col1, #T_e67a1_row0_col2, #T_e67a1_row0_col3, #T_e67a1_row0_col4, #T_e67a1_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_e67a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e67a1_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_e67a1_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_e67a1_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_e67a1_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_e67a1_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_e67a1_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e67a1_level0_row0" class="row_heading level0 row0" >Polynomial Regression (2-Degree)</th>
#       <td id="T_e67a1_row0_col0" class="data row0 col0" >0.676169</td>
#       <td id="T_e67a1_row0_col1" class="data row0 col1" >4.615917</td>
#       <td id="T_e67a1_row0_col2" class="data row0 col2" >38.753553</td>
#       <td id="T_e67a1_row0_col3" class="data row0 col3" >6.225235</td>
#       <td id="T_e67a1_row0_col4" class="data row0 col4" >0.116794</td>
#       <td id="T_e67a1_row0_col5" class="data row0 col5" >0.675764</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2a020_row0_col0, #T_2a020_row0_col1, #T_2a020_row0_col2, #T_2a020_row0_col3, #T_2a020_row0_col4, #T_2a020_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_2a020">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a020_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_2a020_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_2a020_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_2a020_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_2a020_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_2a020_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a020_level0_row0" class="row_heading level0 row0" >Polynomial Regression (3-Degree)</th>
#       <td id="T_2a020_row0_col0" class="data row0 col0" >0.700578</td>
#       <td id="T_2a020_row0_col1" class="data row0 col1" >4.541783</td>
#       <td id="T_2a020_row0_col2" class="data row0 col2" >35.832562</td>
#       <td id="T_2a020_row0_col3" class="data row0 col3" >5.986031</td>
#       <td id="T_2a020_row0_col4" class="data row0 col4" >0.114682</td>
#       <td id="T_2a020_row0_col5" class="data row0 col5" >0.700202</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b7717_row0_col0, #T_b7717_row0_col1, #T_b7717_row0_col2, #T_b7717_row0_col3, #T_b7717_row0_col4, #T_b7717_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b7717">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7717_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_b7717_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_b7717_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_b7717_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_b7717_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_b7717_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7717_level0_row0" class="row_heading level0 row0" >Polynomial Regression (4-Degree)</th>
#       <td id="T_b7717_row0_col0" class="data row0 col0" >0.706101</td>
#       <td id="T_b7717_row0_col1" class="data row0 col1" >4.502111</td>
#       <td id="T_b7717_row0_col2" class="data row0 col2" >35.171553</td>
#       <td id="T_b7717_row0_col3" class="data row0 col3" >5.930561</td>
#       <td id="T_b7717_row0_col4" class="data row0 col4" >0.113712</td>
#       <td id="T_b7717_row0_col5" class="data row0 col5" >0.705733</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e7523_row0_col0, #T_e7523_row0_col1, #T_e7523_row0_col2, #T_e7523_row0_col3, #T_e7523_row0_col4, #T_e7523_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_e7523">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7523_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_e7523_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_e7523_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_e7523_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_e7523_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_e7523_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7523_level0_row0" class="row_heading level0 row0" >Polynomial Regression (5-Degree)</th>
#       <td id="T_e7523_row0_col0" class="data row0 col0" >0.709458</td>
#       <td id="T_e7523_row0_col1" class="data row0 col1" >4.458309</td>
#       <td id="T_e7523_row0_col2" class="data row0 col2" >34.769846</td>
#       <td id="T_e7523_row0_col3" class="data row0 col3" >5.896596</td>
#       <td id="T_e7523_row0_col4" class="data row0 col4" >0.112797</td>
#       <td id="T_e7523_row0_col5" class="data row0 col5" >0.709094</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0a1aa_row0_col0, #T_0a1aa_row0_col1, #T_0a1aa_row0_col2, #T_0a1aa_row0_col3, #T_0a1aa_row0_col4, #T_0a1aa_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_0a1aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a1aa_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_0a1aa_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_0a1aa_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_0a1aa_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_0a1aa_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_0a1aa_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a1aa_level0_row0" class="row_heading level0 row0" >Polynomial Regression (10-Degree)</th>
#       <td id="T_0a1aa_row0_col0" class="data row0 col0" >0.714872</td>
#       <td id="T_0a1aa_row0_col1" class="data row0 col1" >4.425043</td>
#       <td id="T_0a1aa_row0_col2" class="data row0 col2" >34.121893</td>
#       <td id="T_0a1aa_row0_col3" class="data row0 col3" >5.841395</td>
#       <td id="T_0a1aa_row0_col4" class="data row0 col4" >0.112093</td>
#       <td id="T_0a1aa_row0_col5" class="data row0 col5" >0.714515</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Test Set Evaluation

# %%
display(evaluate_model(y_test, y_pred_test_lr, X_test, 'Linear Regression'))
display(evaluate_model(y_test, y_pred_test_lr2, X_test, 'Linear Regression (no intercept)'))
display(evaluate_model(y_test, y_pred_test_poly2, X_test, 'Polynomial Regression (2-Degree)'))
display(evaluate_model(y_test, y_pred_test_poly3, X_test, 'Polynomial Regression (3-Degree)'))
display(evaluate_model(y_test, y_pred_test_poly4, X_test, 'Polynomial Regression (4-Degree)'))
display(evaluate_model(y_test, y_pred_test_poly5, X_test, 'Polynomial Regression (5-Degree)'))
display(evaluate_model(y_test, y_pred_test_poly10, X_test, 'Polynomial Regression (10-Degree)'))
# Out:
# <style type="text/css">
# #T_16c65_row0_col0, #T_16c65_row0_col1, #T_16c65_row0_col2, #T_16c65_row0_col3, #T_16c65_row0_col4, #T_16c65_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_16c65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16c65_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_16c65_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_16c65_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_16c65_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_16c65_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_16c65_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16c65_level0_row0" class="row_heading level0 row0" >Linear Regression</th>
#       <td id="T_16c65_row0_col0" class="data row0 col0" >0.569590</td>
#       <td id="T_16c65_row0_col1" class="data row0 col1" >4.513944</td>
#       <td id="T_16c65_row0_col2" class="data row0 col2" >35.197389</td>
#       <td id="T_16c65_row0_col3" class="data row0 col3" >5.932739</td>
#       <td id="T_16c65_row0_col4" class="data row0 col4" >0.123820</td>
#       <td id="T_16c65_row0_col5" class="data row0 col5" >0.567416</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ea560_row0_col0, #T_ea560_row0_col1, #T_ea560_row0_col2, #T_ea560_row0_col3, #T_ea560_row0_col4, #T_ea560_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_ea560">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea560_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_ea560_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_ea560_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_ea560_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_ea560_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_ea560_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea560_level0_row0" class="row_heading level0 row0" >Linear Regression (no intercept)</th>
#       <td id="T_ea560_row0_col0" class="data row0 col0" >-3.252766</td>
#       <td id="T_ea560_row0_col1" class="data row0 col1" >14.372445</td>
#       <td id="T_ea560_row0_col2" class="data row0 col2" >347.775738</td>
#       <td id="T_ea560_row0_col3" class="data row0 col3" >18.648746</td>
#       <td id="T_ea560_row0_col4" class="data row0 col4" >0.364747</td>
#       <td id="T_ea560_row0_col5" class="data row0 col5" >-3.274245</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_183c0_row0_col0, #T_183c0_row0_col1, #T_183c0_row0_col2, #T_183c0_row0_col3, #T_183c0_row0_col4, #T_183c0_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_183c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_183c0_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_183c0_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_183c0_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_183c0_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_183c0_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_183c0_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_183c0_level0_row0" class="row_heading level0 row0" >Polynomial Regression (2-Degree)</th>
#       <td id="T_183c0_row0_col0" class="data row0 col0" >0.593690</td>
#       <td id="T_183c0_row0_col1" class="data row0 col1" >4.372293</td>
#       <td id="T_183c0_row0_col2" class="data row0 col2" >33.226567</td>
#       <td id="T_183c0_row0_col3" class="data row0 col3" >5.764249</td>
#       <td id="T_183c0_row0_col4" class="data row0 col4" >0.119000</td>
#       <td id="T_183c0_row0_col5" class="data row0 col5" >0.591638</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c73f7_row0_col0, #T_c73f7_row0_col1, #T_c73f7_row0_col2, #T_c73f7_row0_col3, #T_c73f7_row0_col4, #T_c73f7_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_c73f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c73f7_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_c73f7_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_c73f7_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_c73f7_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_c73f7_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_c73f7_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c73f7_level0_row0" class="row_heading level0 row0" >Polynomial Regression (3-Degree)</th>
#       <td id="T_c73f7_row0_col0" class="data row0 col0" >0.605170</td>
#       <td id="T_c73f7_row0_col1" class="data row0 col1" >4.282632</td>
#       <td id="T_c73f7_row0_col2" class="data row0 col2" >32.287774</td>
#       <td id="T_c73f7_row0_col3" class="data row0 col3" >5.682233</td>
#       <td id="T_c73f7_row0_col4" class="data row0 col4" >0.115208</td>
#       <td id="T_c73f7_row0_col5" class="data row0 col5" >0.603176</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4167c_row0_col0, #T_4167c_row0_col1, #T_4167c_row0_col2, #T_4167c_row0_col3, #T_4167c_row0_col4, #T_4167c_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_4167c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4167c_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_4167c_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_4167c_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_4167c_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_4167c_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_4167c_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4167c_level0_row0" class="row_heading level0 row0" >Polynomial Regression (4-Degree)</th>
#       <td id="T_4167c_row0_col0" class="data row0 col0" >0.614049</td>
#       <td id="T_4167c_row0_col1" class="data row0 col1" >4.245119</td>
#       <td id="T_4167c_row0_col2" class="data row0 col2" >31.561637</td>
#       <td id="T_4167c_row0_col3" class="data row0 col3" >5.617974</td>
#       <td id="T_4167c_row0_col4" class="data row0 col4" >0.113732</td>
#       <td id="T_4167c_row0_col5" class="data row0 col5" >0.612100</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d0fc8_row0_col0, #T_d0fc8_row0_col1, #T_d0fc8_row0_col2, #T_d0fc8_row0_col3, #T_d0fc8_row0_col4, #T_d0fc8_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_d0fc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0fc8_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_d0fc8_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_d0fc8_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_d0fc8_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_d0fc8_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_d0fc8_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0fc8_level0_row0" class="row_heading level0 row0" >Polynomial Regression (5-Degree)</th>
#       <td id="T_d0fc8_row0_col0" class="data row0 col0" >0.614760</td>
#       <td id="T_d0fc8_row0_col1" class="data row0 col1" >4.269145</td>
#       <td id="T_d0fc8_row0_col2" class="data row0 col2" >31.503539</td>
#       <td id="T_d0fc8_row0_col3" class="data row0 col3" >5.612801</td>
#       <td id="T_d0fc8_row0_col4" class="data row0 col4" >0.114762</td>
#       <td id="T_d0fc8_row0_col5" class="data row0 col5" >0.612814</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2a10d_row0_col0, #T_2a10d_row0_col1, #T_2a10d_row0_col2, #T_2a10d_row0_col3, #T_2a10d_row0_col4, #T_2a10d_row0_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_2a10d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a10d_level0_col0" class="col_heading level0 col0" >R-squared</th>
#       <th id="T_2a10d_level0_col1" class="col_heading level0 col1" >Mean Absolute Error</th>
#       <th id="T_2a10d_level0_col2" class="col_heading level0 col2" >Mean Squared Error</th>
#       <th id="T_2a10d_level0_col3" class="col_heading level0 col3" >Root Mean Squared Error</th>
#       <th id="T_2a10d_level0_col4" class="col_heading level0 col4" >Mean Absolute Percentage Error</th>
#       <th id="T_2a10d_level0_col5" class="col_heading level0 col5" >Adjusted R-squared</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a10d_level0_row0" class="row_heading level0 row0" >Polynomial Regression (10-Degree)</th>
#       <td id="T_2a10d_row0_col0" class="data row0 col0" >0.622572</td>
#       <td id="T_2a10d_row0_col1" class="data row0 col1" >4.237094</td>
#       <td id="T_2a10d_row0_col2" class="data row0 col2" >30.864727</td>
#       <td id="T_2a10d_row0_col3" class="data row0 col3" >5.555603</td>
#       <td id="T_2a10d_row0_col4" class="data row0 col4" >0.113822</td>
#       <td id="T_2a10d_row0_col5" class="data row0 col5" >0.620665</td>
#     </tr>
#   </tbody>
# </table>
